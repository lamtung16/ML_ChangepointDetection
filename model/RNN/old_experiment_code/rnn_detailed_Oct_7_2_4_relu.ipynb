# %%
import pandas as pd
import lzma
import torch
import torch.nn as nn
import numpy as np
import random
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

# %%
dataset = 'detailed'
test_fold = 1

nonlinearity='relu'
hidden_size = 4
num_layers = 2

max_epoch = 1000
patience = 50

# %%
# Hinged Square Loss
class SquaredHingeLoss(nn.Module):
    def __init__(self, margin=1):
        super(SquaredHingeLoss, self).__init__()
        self.margin = margin

    def forward(self, predicted, y):
        low, high = y[:, 0:1], y[:, 1:2]
        loss_low = torch.relu(low - predicted + self.margin)
        loss_high = torch.relu(predicted - high + self.margin)
        loss = loss_low + loss_high
        return torch.mean(torch.square(loss))

# %%
# Define the RNN model
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, nonlinearity=nonlinearity)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x, lengths):
        # x is PackedSequence
        packed_output, hidden = self.rnn(x)
        # Get the last hidden state from the last layer
        last_hidden = hidden[-1]  # Shape: (batch_size, hidden_size)
        x = self.fc(last_hidden)
        x = torch.relu(x + 10) - torch.relu(x - 10) - 10
        return x

# %%
# Custom Dataset
class SequenceDataset(torch.utils.data.Dataset):
    def __init__(self, sequences, targets):
        self.sequences = sequences
        self.targets = targets

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        return self.sequences[idx], self.targets[idx]

# %%
# Collate function for DataLoader
def collate_fn(batch):
    sequences, targets = zip(*batch)
    # Get lengths of each sequence
    lengths = torch.tensor([len(seq) for seq in sequences], dtype=torch.long)
    # Pad sequences to the same length
    sequences_padded = torch.nn.utils.rnn.pad_sequence(sequences, batch_first=True)
    # Stack targets
    targets = torch.stack(targets)
    return sequences_padded.unsqueeze(-1), targets, lengths

# %%
# Function to compute loss value
def get_loss_value(model, data_loader, criterion):
    model.eval()
    total_loss = 0
    total_samples = 0
    with torch.no_grad():
        for seq_inputs, targets, lengths in data_loader:
            seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
            outputs = model(seq_inputs_packed, lengths)
            loss = criterion(outputs, targets.unsqueeze(-1))
            batch_size = seq_inputs.size(0)
            total_loss += loss.item() * batch_size
            total_samples += batch_size
    average_loss = total_loss / total_samples
    return average_loss

# %%
# Function to test the model
def test_model(model, data_loader):
    model.eval()
    predictions = []
    with torch.no_grad():
        for seq_inputs, _, lengths in data_loader:
            seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
            outputs = model(seq_inputs_packed, lengths)
            predictions.extend(outputs.squeeze(-1).tolist())
    return predictions

# %%
# Load data
file_path = f'../../sequence_data/{dataset}/profiles.csv.xz'
with lzma.open(file_path, 'rt') as file:
    signal_df = pd.read_csv(file)

seqs = tuple(signal_df.groupby('sequenceID'))

# Load data
folds_df = pd.read_csv(f'../../training_data/{dataset}/folds.csv')
target_df = pd.read_csv(f'../../training_data/{dataset}/target.csv')

# Split data into training and test sets
train_ids = folds_df[folds_df['fold'] != test_fold]['sequenceID']
test_ids = folds_df[folds_df['fold'] == test_fold]['sequenceID']

# Train sequences
train_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(train_ids)]

# Test sequences
test_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(test_ids)]

# Targets
target_df_train = target_df[target_df['sequenceID'].isin(train_ids)]
target_df_test = target_df[target_df['sequenceID'].isin(test_ids)]
y_train = torch.tensor(target_df_train.iloc[:, 1:].to_numpy(), dtype=torch.float32)
y_test = torch.tensor(target_df_test.iloc[:, 1:].to_numpy(), dtype=torch.float32)

# Split train into subtrain and validation (80% subtrain, 20% validation)
train_seqs, val_seqs, y_train, y_val = train_test_split(train_seqs, y_train, test_size=0.2, random_state=42)

# Create datasets and dataloaders
batch_size = 64

train_dataset = SequenceDataset(train_seqs, y_train)
val_dataset = SequenceDataset(val_seqs, y_val)
test_dataset = SequenceDataset(test_seqs, y_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

# %%
# Initialize the model, loss function, and optimizer
model = RNNModel(1, hidden_size, num_layers)
criterion = SquaredHingeLoss()
optimizer = torch.optim.Adam(model.parameters())

# Initialize variables for best validation loss and best model
best_val_loss = float('inf')    # Set best validation loss to infinity initially
patience_counter = 0            # Counter for early stopping
best_model_state = None         # Variable to store the best model parameters

# Training loop
for epoch in range(max_epoch):
    model.train()
    total_loss = 0
    total_samples = 0

    for seq_inputs, targets, lengths in train_loader:
        optimizer.zero_grad()
        seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
        outputs = model(seq_inputs_packed, lengths)
        loss = criterion(outputs, targets.unsqueeze(-1))

        # Stop training if loss is NaN
        if torch.isnan(loss):
            print(f'Stopping training at epoch {epoch} due to NaN loss.')
            break

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        batch_size = seq_inputs.size(0)
        total_loss += loss.item() * batch_size
        total_samples += batch_size

    # Calculate average loss for this epoch (training)
    average_loss = total_loss / total_samples

    # Validation step
    average_val_loss  = get_loss_value(model, val_loader, criterion)
    average_test_loss = get_loss_value(model, test_loader, criterion)

    if epoch % 1 == 0:
        print(f'Test fold {test_fold} \t Epoch [{epoch:3d}] \t Train Loss: {average_loss:.8f} \t Val Loss: {average_val_loss:.8f} \t Test Loss: {average_test_loss:.8f}')

    # Early stopping logic based on validation loss
    if average_val_loss < best_val_loss:
        best_val_loss = average_val_loss  # Update best validation loss
        patience_counter = 0  # Reset patience counter

        # Save the best model parameters in memory
        best_model_state = model.state_dict()  # Store the model parameters
    else:
        patience_counter += 1  # Increment patience counter

    # Stop training if patience is exceeded or NaN is detected
    if patience_counter >= patience or torch.isnan(loss):
        if torch.isnan(loss):
            print(f'Training stopped due to NaN loss at epoch {epoch}.')
        else:
            print(f'Early stopping triggered after {epoch + 1} epochs.')
        break

# After training, you can restore the best model parameters if needed
if best_model_state is not None:
    model.load_state_dict(best_model_state)
    model.eval()  # Set the model to evaluation mode

# Test the model and collect outputs
pred_lldas = test_model(model, test_loader)

# Save to CSV
lldas_df = pd.DataFrame(list(zip(test_ids, pred_lldas)), columns=['sequenceID', 'llda'])
lldas_df.to_csv(f'predictions/proposed.{dataset}.{hidden_size}.{num_layers}.{nonlinearity}.{patience}.{test_fold}.csv', index=False)
# Out:
# Test fold 1 	 Epoch [  0] 	 Train Loss: 0.45197881 	 Val Loss: 0.46942813 	 Test Loss: 0.45823197
# Test fold 1 	 Epoch [  1] 	 Train Loss: 0.44988771 	 Val Loss: 0.46533849 	 Test Loss: 0.45872002
# Test fold 1 	 Epoch [  2] 	 Train Loss: 0.44809355 	 Val Loss: 0.46425054 	 Test Loss: 0.45926157
# Test fold 1 	 Epoch [  3] 	 Train Loss: 0.44822425 	 Val Loss: 0.46301922 	 Test Loss: 0.46033479
# Test fold 1 	 Epoch [  4] 	 Train Loss: 0.44786178 	 Val Loss: 0.46352678 	 Test Loss: 0.45981664
# Test fold 1 	 Epoch [  5] 	 Train Loss: 0.44753111 	 Val Loss: 0.46323413 	 Test Loss: 0.46010004
# Test fold 1 	 Epoch [  6] 	 Train Loss: 0.44749257 	 Val Loss: 0.46283229 	 Test Loss: 0.46058717
# Test fold 1 	 Epoch [  7] 	 Train Loss: 0.44768854 	 Val Loss: 0.46248367 	 Test Loss: 0.46111804
# Test fold 1 	 Epoch [  8] 	 Train Loss: 0.44744888 	 Val Loss: 0.46277983 	 Test Loss: 0.46066648
# Test fold 1 	 Epoch [  9] 	 Train Loss: 0.44751620 	 Val Loss: 0.46272315 	 Test Loss: 0.46074765
# Test fold 1 	 Epoch [ 10] 	 Train Loss: 0.44775107 	 Val Loss: 0.46270074 	 Test Loss: 0.46077608
# Test fold 1 	 Epoch [ 11] 	 Train Loss: 0.44755846 	 Val Loss: 0.46257037 	 Test Loss: 0.46098509
# Test fold 1 	 Epoch [ 12] 	 Train Loss: 0.44749557 	 Val Loss: 0.46260677 	 Test Loss: 0.46094336
# Test fold 1 	 Epoch [ 13] 	 Train Loss: 0.44759611 	 Val Loss: 0.46258432 	 Test Loss: 0.46098082
# Test fold 1 	 Epoch [ 14] 	 Train Loss: 0.44763810 	 Val Loss: 0.46248573 	 Test Loss: 0.46114041
# Test fold 1 	 Epoch [ 15] 	 Train Loss: 0.44759988 	 Val Loss: 0.46271842 	 Test Loss: 0.46077098
# Test fold 1 	 Epoch [ 16] 	 Train Loss: 0.44754897 	 Val Loss: 0.46276126 	 Test Loss: 0.46071774
# Test fold 1 	 Epoch [ 17] 	 Train Loss: 0.44762764 	 Val Loss: 0.46300596 	 Test Loss: 0.46041516
# Test fold 1 	 Epoch [ 18] 	 Train Loss: 0.44742473 	 Val Loss: 0.46265696 	 Test Loss: 0.46097188
# Test fold 1 	 Epoch [ 19] 	 Train Loss: 0.44772938 	 Val Loss: 0.46260527 	 Test Loss: 0.46105121
# Test fold 1 	 Epoch [ 20] 	 Train Loss: 0.44762834 	 Val Loss: 0.46281332 	 Test Loss: 0.46074391
# Test fold 1 	 Epoch [ 21] 	 Train Loss: 0.44757369 	 Val Loss: 0.46262149 	 Test Loss: 0.46102070
# Test fold 1 	 Epoch [ 22] 	 Train Loss: 0.44757124 	 Val Loss: 0.46264595 	 Test Loss: 0.46096897
# Test fold 1 	 Epoch [ 23] 	 Train Loss: 0.44778643 	 Val Loss: 0.46296560 	 Test Loss: 0.46049670
# Test fold 1 	 Epoch [ 24] 	 Train Loss: 0.44760378 	 Val Loss: 0.46239314 	 Test Loss: 0.46137704
# Test fold 1 	 Epoch [ 25] 	 Train Loss: 0.44753488 	 Val Loss: 0.46271915 	 Test Loss: 0.46085706
# Test fold 1 	 Epoch [ 26] 	 Train Loss: 0.44754836 	 Val Loss: 0.46299612 	 Test Loss: 0.46049413
# Test fold 1 	 Epoch [ 27] 	 Train Loss: 0.44795125 	 Val Loss: 0.46272076 	 Test Loss: 0.46087094
# Test fold 1 	 Epoch [ 28] 	 Train Loss: 0.44751292 	 Val Loss: 0.46269505 	 Test Loss: 0.46094195
# Test fold 1 	 Epoch [ 29] 	 Train Loss: 0.44770521 	 Val Loss: 0.46320715 	 Test Loss: 0.46028058
# Test fold 1 	 Epoch [ 30] 	 Train Loss: 0.44767815 	 Val Loss: 0.46241685 	 Test Loss: 0.46139545
# Test fold 1 	 Epoch [ 31] 	 Train Loss: 0.44742603 	 Val Loss: 0.46278137 	 Test Loss: 0.46081989
# Test fold 1 	 Epoch [ 32] 	 Train Loss: 0.44746331 	 Val Loss: 0.46284043 	 Test Loss: 0.46073096
# Test fold 1 	 Epoch [ 33] 	 Train Loss: 0.44785513 	 Val Loss: 0.46258311 	 Test Loss: 0.46106908
# Test fold 1 	 Epoch [ 34] 	 Train Loss: 0.44777594 	 Val Loss: 0.46297954 	 Test Loss: 0.46052707
# Test fold 1 	 Epoch [ 35] 	 Train Loss: 0.44778273 	 Val Loss: 0.46260008 	 Test Loss: 0.46109190
# Test fold 1 	 Epoch [ 36] 	 Train Loss: 0.44748425 	 Val Loss: 0.46258584 	 Test Loss: 0.46110268
# Test fold 1 	 Epoch [ 37] 	 Train Loss: 0.44768265 	 Val Loss: 0.46281883 	 Test Loss: 0.46078317
# Test fold 1 	 Epoch [ 38] 	 Train Loss: 0.44752447 	 Val Loss: 0.46301006 	 Test Loss: 0.46053576
# Test fold 1 	 Epoch [ 39] 	 Train Loss: 0.44752468 	 Val Loss: 0.46262131 	 Test Loss: 0.46106428
# Test fold 1 	 Epoch [ 40] 	 Train Loss: 0.44755671 	 Val Loss: 0.46259040 	 Test Loss: 0.46108871
# Test fold 1 	 Epoch [ 41] 	 Train Loss: 0.44751418 	 Val Loss: 0.46250801 	 Test Loss: 0.46121553
# Test fold 1 	 Epoch [ 42] 	 Train Loss: 0.44745422 	 Val Loss: 0.46264713 	 Test Loss: 0.46099487
# Test fold 1 	 Epoch [ 43] 	 Train Loss: 0.44753192 	 Val Loss: 0.46294291 	 Test Loss: 0.46059288
# Test fold 1 	 Epoch [ 44] 	 Train Loss: 0.44750471 	 Val Loss: 0.46265871 	 Test Loss: 0.46100011
# Test fold 1 	 Epoch [ 45] 	 Train Loss: 0.44774520 	 Val Loss: 0.46304050 	 Test Loss: 0.46047013
# Test fold 1 	 Epoch [ 46] 	 Train Loss: 0.44764137 	 Val Loss: 0.46238345 	 Test Loss: 0.46145710
# Test fold 1 	 Epoch [ 47] 	 Train Loss: 0.44746783 	 Val Loss: 0.46276835 	 Test Loss: 0.46083809
# Test fold 1 	 Epoch [ 48] 	 Train Loss: 0.44761709 	 Val Loss: 0.46264518 	 Test Loss: 0.46099099
# Test fold 1 	 Epoch [ 49] 	 Train Loss: 0.44738499 	 Val Loss: 0.46279154 	 Test Loss: 0.46074214
# Test fold 1 	 Epoch [ 50] 	 Train Loss: 0.44747436 	 Val Loss: 0.46286613 	 Test Loss: 0.46064131
# Test fold 1 	 Epoch [ 51] 	 Train Loss: 0.44746927 	 Val Loss: 0.46282687 	 Test Loss: 0.46068844
# Test fold 1 	 Epoch [ 52] 	 Train Loss: 0.44755550 	 Val Loss: 0.46276503 	 Test Loss: 0.46078996
# Test fold 1 	 Epoch [ 53] 	 Train Loss: 0.44766179 	 Val Loss: 0.46300774 	 Test Loss: 0.46046379
# Test fold 1 	 Epoch [ 54] 	 Train Loss: 0.44755304 	 Val Loss: 0.46273526 	 Test Loss: 0.46082686
# Test fold 1 	 Epoch [ 55] 	 Train Loss: 0.44760973 	 Val Loss: 0.46260115 	 Test Loss: 0.46105436
# Test fold 1 	 Epoch [ 56] 	 Train Loss: 0.44801144 	 Val Loss: 0.46335966 	 Test Loss: 0.46012491
# Test fold 1 	 Epoch [ 57] 	 Train Loss: 0.44753993 	 Val Loss: 0.46269581 	 Test Loss: 0.46095633
# Test fold 1 	 Epoch [ 58] 	 Train Loss: 0.44771670 	 Val Loss: 0.46253869 	 Test Loss: 0.46121067
# Test fold 1 	 Epoch [ 59] 	 Train Loss: 0.44783114 	 Val Loss: 0.46310672 	 Test Loss: 0.46042642
# Test fold 1 	 Epoch [ 60] 	 Train Loss: 0.44740533 	 Val Loss: 0.46274752 	 Test Loss: 0.46089357
# Test fold 1 	 Epoch [ 61] 	 Train Loss: 0.44766226 	 Val Loss: 0.46257410 	 Test Loss: 0.46113614
# Test fold 1 	 Epoch [ 62] 	 Train Loss: 0.44750284 	 Val Loss: 0.46254844 	 Test Loss: 0.46119744
# Test fold 1 	 Epoch [ 63] 	 Train Loss: 0.44751615 	 Val Loss: 0.46259349 	 Test Loss: 0.46113420
# Test fold 1 	 Epoch [ 64] 	 Train Loss: 0.44769213 	 Val Loss: 0.46268008 	 Test Loss: 0.46098957
# Test fold 1 	 Epoch [ 65] 	 Train Loss: 0.44744341 	 Val Loss: 0.46305195 	 Test Loss: 0.46046558
# Test fold 1 	 Epoch [ 66] 	 Train Loss: 0.44754367 	 Val Loss: 0.46306535 	 Test Loss: 0.46044873
# Test fold 1 	 Epoch [ 67] 	 Train Loss: 0.44756883 	 Val Loss: 0.46258886 	 Test Loss: 0.46110786
# Test fold 1 	 Epoch [ 68] 	 Train Loss: 0.44751456 	 Val Loss: 0.46288780 	 Test Loss: 0.46066395
# Test fold 1 	 Epoch [ 69] 	 Train Loss: 0.44775998 	 Val Loss: 0.46289105 	 Test Loss: 0.46066288
# Test fold 1 	 Epoch [ 70] 	 Train Loss: 0.44777877 	 Val Loss: 0.46295083 	 Test Loss: 0.46057073
# Test fold 1 	 Epoch [ 71] 	 Train Loss: 0.44756704 	 Val Loss: 0.46231174 	 Test Loss: 0.46155011
# Test fold 1 	 Epoch [ 72] 	 Train Loss: 0.44764438 	 Val Loss: 0.46260459 	 Test Loss: 0.46099512
# Test fold 1 	 Epoch [ 73] 	 Train Loss: 0.44773072 	 Val Loss: 0.46298332 	 Test Loss: 0.46048888
# Test fold 1 	 Epoch [ 74] 	 Train Loss: 0.44750398 	 Val Loss: 0.46272215 	 Test Loss: 0.46082975
# Test fold 1 	 Epoch [ 75] 	 Train Loss: 0.44743809 	 Val Loss: 0.46262301 	 Test Loss: 0.46098317
# Test fold 1 	 Epoch [ 76] 	 Train Loss: 0.44750825 	 Val Loss: 0.46259151 	 Test Loss: 0.46101609
# Test fold 1 	 Epoch [ 77] 	 Train Loss: 0.44767251 	 Val Loss: 0.46240539 	 Test Loss: 0.46135526
# Test fold 1 	 Epoch [ 78] 	 Train Loss: 0.44750349 	 Val Loss: 0.46281070 	 Test Loss: 0.46070513
# Test fold 1 	 Epoch [ 79] 	 Train Loss: 0.44755211 	 Val Loss: 0.46279349 	 Test Loss: 0.46070643
# Test fold 1 	 Epoch [ 80] 	 Train Loss: 0.44788242 	 Val Loss: 0.46263540 	 Test Loss: 0.46094001
# Test fold 1 	 Epoch [ 81] 	 Train Loss: 0.44750835 	 Val Loss: 0.46300698 	 Test Loss: 0.46048821
# Test fold 1 	 Epoch [ 82] 	 Train Loss: 0.44743336 	 Val Loss: 0.46282813 	 Test Loss: 0.46073467
# Test fold 1 	 Epoch [ 83] 	 Train Loss: 0.44754937 	 Val Loss: 0.46289959 	 Test Loss: 0.46064194
# Test fold 1 	 Epoch [ 84] 	 Train Loss: 0.44754126 	 Val Loss: 0.46277315 	 Test Loss: 0.46081480
# Test fold 1 	 Epoch [ 85] 	 Train Loss: 0.44743535 	 Val Loss: 0.46278873 	 Test Loss: 0.46080525
# Test fold 1 	 Epoch [ 86] 	 Train Loss: 0.44766233 	 Val Loss: 0.46276867 	 Test Loss: 0.46082274
# Test fold 1 	 Epoch [ 87] 	 Train Loss: 0.44769402 	 Val Loss: 0.46305604 	 Test Loss: 0.46039772
# Test fold 1 	 Epoch [ 88] 	 Train Loss: 0.44751934 	 Val Loss: 0.46264549 	 Test Loss: 0.46093182
# Test fold 1 	 Epoch [ 89] 	 Train Loss: 0.44754399 	 Val Loss: 0.46270466 	 Test Loss: 0.46087818
# Test fold 1 	 Epoch [ 90] 	 Train Loss: 0.44748326 	 Val Loss: 0.46268364 	 Test Loss: 0.46091484
# Test fold 1 	 Epoch [ 91] 	 Train Loss: 0.44747766 	 Val Loss: 0.46273830 	 Test Loss: 0.46082113
# Test fold 1 	 Epoch [ 92] 	 Train Loss: 0.44763452 	 Val Loss: 0.46258407 	 Test Loss: 0.46108522
# Test fold 1 	 Epoch [ 93] 	 Train Loss: 0.44744003 	 Val Loss: 0.46270807 	 Test Loss: 0.46084624
# Test fold 1 	 Epoch [ 94] 	 Train Loss: 0.44742430 	 Val Loss: 0.46300092 	 Test Loss: 0.46046612
# Test fold 1 	 Epoch [ 95] 	 Train Loss: 0.44757090 	 Val Loss: 0.46272974 	 Test Loss: 0.46081370
# Test fold 1 	 Epoch [ 96] 	 Train Loss: 0.44749367 	 Val Loss: 0.46306417 	 Test Loss: 0.46037726
# Test fold 1 	 Epoch [ 97] 	 Train Loss: 0.44742954 	 Val Loss: 0.46282895 	 Test Loss: 0.46067591
# Test fold 1 	 Epoch [ 98] 	 Train Loss: 0.44748624 	 Val Loss: 0.46265293 	 Test Loss: 0.46093913
# Test fold 1 	 Epoch [ 99] 	 Train Loss: 0.44750148 	 Val Loss: 0.46257599 	 Test Loss: 0.46104162
# Test fold 1 	 Epoch [100] 	 Train Loss: 0.44750781 	 Val Loss: 0.46288610 	 Test Loss: 0.46059668
# Test fold 1 	 Epoch [101] 	 Train Loss: 0.44752739 	 Val Loss: 0.46305989 	 Test Loss: 0.46040973
# Test fold 1 	 Epoch [102] 	 Train Loss: 0.44761395 	 Val Loss: 0.46302140 	 Test Loss: 0.46046626
# Test fold 1 	 Epoch [103] 	 Train Loss: 0.44758781 	 Val Loss: 0.46271246 	 Test Loss: 0.46087715
# Test fold 1 	 Epoch [104] 	 Train Loss: 0.44782226 	 Val Loss: 0.46285635 	 Test Loss: 0.46066140
# Test fold 1 	 Epoch [105] 	 Train Loss: 0.44759545 	 Val Loss: 0.46235300 	 Test Loss: 0.46153357
# Test fold 1 	 Epoch [106] 	 Train Loss: 0.44740767 	 Val Loss: 0.46296902 	 Test Loss: 0.46050868
# Test fold 1 	 Epoch [107] 	 Train Loss: 0.44751267 	 Val Loss: 0.46277110 	 Test Loss: 0.46077615
# Test fold 1 	 Epoch [108] 	 Train Loss: 0.44759882 	 Val Loss: 0.46277348 	 Test Loss: 0.46076596
# Test fold 1 	 Epoch [109] 	 Train Loss: 0.44783021 	 Val Loss: 0.46322439 	 Test Loss: 0.46018675
# Test fold 1 	 Epoch [110] 	 Train Loss: 0.44762323 	 Val Loss: 0.46252463 	 Test Loss: 0.46112474
# Test fold 1 	 Epoch [111] 	 Train Loss: 0.44748872 	 Val Loss: 0.46260591 	 Test Loss: 0.46103069
# Test fold 1 	 Epoch [112] 	 Train Loss: 0.44750523 	 Val Loss: 0.46310236 	 Test Loss: 0.46036111
# Test fold 1 	 Epoch [113] 	 Train Loss: 0.44758373 	 Val Loss: 0.46292496 	 Test Loss: 0.46057267
# Test fold 1 	 Epoch [114] 	 Train Loss: 0.44756903 	 Val Loss: 0.46249553 	 Test Loss: 0.46119077
# Test fold 1 	 Epoch [115] 	 Train Loss: 0.44766561 	 Val Loss: 0.46281012 	 Test Loss: 0.46074484
# Test fold 1 	 Epoch [116] 	 Train Loss: 0.44758973 	 Val Loss: 0.46268940 	 Test Loss: 0.46092021
# Test fold 1 	 Epoch [117] 	 Train Loss: 0.44746472 	 Val Loss: 0.46272367 	 Test Loss: 0.46087473
# Test fold 1 	 Epoch [118] 	 Train Loss: 0.44750345 	 Val Loss: 0.46292188 	 Test Loss: 0.46059628
# Test fold 1 	 Epoch [119] 	 Train Loss: 0.44755436 	 Val Loss: 0.46291745 	 Test Loss: 0.46055213
# Test fold 1 	 Epoch [120] 	 Train Loss: 0.44751731 	 Val Loss: 0.46269365 	 Test Loss: 0.46085354
# Test fold 1 	 Epoch [121] 	 Train Loss: 0.44764094 	 Val Loss: 0.46288953 	 Test Loss: 0.46059625
# Early stopping triggered after 122 epochs.
