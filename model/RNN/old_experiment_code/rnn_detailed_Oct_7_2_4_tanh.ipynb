# %%
import pandas as pd
import lzma
import torch
import torch.nn as nn
import numpy as np
import random
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

# %%
dataset = 'detailed'
test_fold = 1

nonlinearity='tanh'
hidden_size = 4
num_layers = 2

max_epoch = 1000
patience = 50

# %%
# Hinged Square Loss
class SquaredHingeLoss(nn.Module):
    def __init__(self, margin=1):
        super(SquaredHingeLoss, self).__init__()
        self.margin = margin

    def forward(self, predicted, y):
        low, high = y[:, 0:1], y[:, 1:2]
        loss_low = torch.relu(low - predicted + self.margin)
        loss_high = torch.relu(predicted - high + self.margin)
        loss = loss_low + loss_high
        return torch.mean(torch.square(loss))

# %%
# Define the RNN model
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, nonlinearity=nonlinearity)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x, lengths):
        # x is PackedSequence
        packed_output, hidden = self.rnn(x)
        # Get the last hidden state from the last layer
        last_hidden = hidden[-1]  # Shape: (batch_size, hidden_size)
        x = self.fc(last_hidden)
        x = torch.relu(x + 10) - torch.relu(x - 10) - 10
        return x

# %%
# Custom Dataset
class SequenceDataset(torch.utils.data.Dataset):
    def __init__(self, sequences, targets):
        self.sequences = sequences
        self.targets = targets

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        return self.sequences[idx], self.targets[idx]

# %%
# Collate function for DataLoader
def collate_fn(batch):
    sequences, targets = zip(*batch)
    # Get lengths of each sequence
    lengths = torch.tensor([len(seq) for seq in sequences], dtype=torch.long)
    # Pad sequences to the same length
    sequences_padded = torch.nn.utils.rnn.pad_sequence(sequences, batch_first=True)
    # Stack targets
    targets = torch.stack(targets)
    return sequences_padded.unsqueeze(-1), targets, lengths

# %%
# Function to compute loss value
def get_loss_value(model, data_loader, criterion):
    model.eval()
    total_loss = 0
    total_samples = 0
    with torch.no_grad():
        for seq_inputs, targets, lengths in data_loader:
            seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
            outputs = model(seq_inputs_packed, lengths)
            loss = criterion(outputs, targets.unsqueeze(-1))
            batch_size = seq_inputs.size(0)
            total_loss += loss.item() * batch_size
            total_samples += batch_size
    average_loss = total_loss / total_samples
    return average_loss

# %%
# Function to test the model
def test_model(model, data_loader):
    model.eval()
    predictions = []
    with torch.no_grad():
        for seq_inputs, _, lengths in data_loader:
            seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
            outputs = model(seq_inputs_packed, lengths)
            predictions.extend(outputs.squeeze(-1).tolist())
    return predictions

# %%
# Load data
file_path = f'../../sequence_data/{dataset}/profiles.csv.xz'
with lzma.open(file_path, 'rt') as file:
    signal_df = pd.read_csv(file)

seqs = tuple(signal_df.groupby('sequenceID'))

# Load data
folds_df = pd.read_csv(f'../../training_data/{dataset}/folds.csv')
target_df = pd.read_csv(f'../../training_data/{dataset}/target.csv')

# Split data into training and test sets
train_ids = folds_df[folds_df['fold'] != test_fold]['sequenceID']
test_ids = folds_df[folds_df['fold'] == test_fold]['sequenceID']

# Train sequences
train_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(train_ids)]

# Test sequences
test_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(test_ids)]

# Targets
target_df_train = target_df[target_df['sequenceID'].isin(train_ids)]
target_df_test = target_df[target_df['sequenceID'].isin(test_ids)]
y_train = torch.tensor(target_df_train.iloc[:, 1:].to_numpy(), dtype=torch.float32)
y_test = torch.tensor(target_df_test.iloc[:, 1:].to_numpy(), dtype=torch.float32)

# Split train into subtrain and validation (80% subtrain, 20% validation)
train_seqs, val_seqs, y_train, y_val = train_test_split(train_seqs, y_train, test_size=0.2, random_state=42)

# Create datasets and dataloaders
batch_size = 64

train_dataset = SequenceDataset(train_seqs, y_train)
val_dataset = SequenceDataset(val_seqs, y_val)
test_dataset = SequenceDataset(test_seqs, y_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

# %%
# Initialize the model, loss function, and optimizer
model = RNNModel(1, hidden_size, num_layers)
criterion = SquaredHingeLoss()
optimizer = torch.optim.Adam(model.parameters())

# Initialize variables for best validation loss and best model
best_val_loss = float('inf')    # Set best validation loss to infinity initially
patience_counter = 0            # Counter for early stopping
best_model_state = None         # Variable to store the best model parameters

# Training loop
for epoch in range(max_epoch):
    model.train()
    total_loss = 0
    total_samples = 0

    for seq_inputs, targets, lengths in train_loader:
        optimizer.zero_grad()
        seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
        outputs = model(seq_inputs_packed, lengths)
        loss = criterion(outputs, targets.unsqueeze(-1))

        # Stop training if loss is NaN
        if torch.isnan(loss):
            print(f'Stopping training at epoch {epoch} due to NaN loss.')
            break

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        batch_size = seq_inputs.size(0)
        total_loss += loss.item() * batch_size
        total_samples += batch_size

    # Calculate average loss for this epoch (training)
    average_loss = total_loss / total_samples

    # Validation step
    average_val_loss  = get_loss_value(model, val_loader, criterion)
    average_test_loss = get_loss_value(model, test_loader, criterion)

    if epoch % 1 == 0:
        print(f'Test fold {test_fold} \t Epoch [{epoch:3d}] \t Train Loss: {average_loss:.8f} \t Val Loss: {average_val_loss:.8f} \t Test Loss: {average_test_loss:.8f}')

    # Early stopping logic based on validation loss
    if average_val_loss < best_val_loss:
        best_val_loss = average_val_loss  # Update best validation loss
        patience_counter = 0  # Reset patience counter

        # Save the best model parameters in memory
        best_model_state = model.state_dict()  # Store the model parameters
    else:
        patience_counter += 1  # Increment patience counter

    # Stop training if patience is exceeded or NaN is detected
    if patience_counter >= patience or torch.isnan(loss):
        if torch.isnan(loss):
            print(f'Training stopped due to NaN loss at epoch {epoch}.')
        else:
            print(f'Early stopping triggered after {epoch + 1} epochs.')
        break

# After training, you can restore the best model parameters if needed
if best_model_state is not None:
    model.load_state_dict(best_model_state)
    model.eval()  # Set the model to evaluation mode

# Test the model and collect outputs
pred_lldas = test_model(model, test_loader)

# Save to CSV
lldas_df = pd.DataFrame(list(zip(test_ids, pred_lldas)), columns=['sequenceID', 'llda'])
lldas_df.to_csv(f'predictions/proposed.{dataset}.{hidden_size}.{num_layers}.{nonlinearity}.{patience}.{test_fold}.csv', index=False)
# Out:
# Test fold 1 	 Epoch [  0] 	 Train Loss: 0.72063636 	 Val Loss: 0.66556800 	 Test Loss: 0.60308572
# Test fold 1 	 Epoch [  1] 	 Train Loss: 0.59340156 	 Val Loss: 0.57649713 	 Test Loss: 0.52672884
# Test fold 1 	 Epoch [  2] 	 Train Loss: 0.51985253 	 Val Loss: 0.51660518 	 Test Loss: 0.48109980
# Test fold 1 	 Epoch [  3] 	 Train Loss: 0.47406232 	 Val Loss: 0.48024168 	 Test Loss: 0.46070195
# Test fold 1 	 Epoch [  4] 	 Train Loss: 0.45323013 	 Val Loss: 0.46787203 	 Test Loss: 0.45825563
# Test fold 1 	 Epoch [  5] 	 Train Loss: 0.44921079 	 Val Loss: 0.46359825 	 Test Loss: 0.46015207
# Test fold 1 	 Epoch [  6] 	 Train Loss: 0.44771836 	 Val Loss: 0.46347476 	 Test Loss: 0.46025506
# Test fold 1 	 Epoch [  7] 	 Train Loss: 0.44784856 	 Val Loss: 0.46319819 	 Test Loss: 0.46056959
# Test fold 1 	 Epoch [  8] 	 Train Loss: 0.44786493 	 Val Loss: 0.46278916 	 Test Loss: 0.46118042
# Test fold 1 	 Epoch [  9] 	 Train Loss: 0.44785437 	 Val Loss: 0.46298852 	 Test Loss: 0.46080802
# Test fold 1 	 Epoch [ 10] 	 Train Loss: 0.44799569 	 Val Loss: 0.46294180 	 Test Loss: 0.46084889
# Test fold 1 	 Epoch [ 11] 	 Train Loss: 0.44772692 	 Val Loss: 0.46309664 	 Test Loss: 0.46058527
# Test fold 1 	 Epoch [ 12] 	 Train Loss: 0.44761867 	 Val Loss: 0.46292844 	 Test Loss: 0.46080701
# Test fold 1 	 Epoch [ 13] 	 Train Loss: 0.44822256 	 Val Loss: 0.46252264 	 Test Loss: 0.46151236
# Test fold 1 	 Epoch [ 14] 	 Train Loss: 0.44786904 	 Val Loss: 0.46279966 	 Test Loss: 0.46098561
# Test fold 1 	 Epoch [ 15] 	 Train Loss: 0.44753922 	 Val Loss: 0.46322476 	 Test Loss: 0.46037455
# Test fold 1 	 Epoch [ 16] 	 Train Loss: 0.44766557 	 Val Loss: 0.46284613 	 Test Loss: 0.46087092
# Test fold 1 	 Epoch [ 17] 	 Train Loss: 0.44776949 	 Val Loss: 0.46286728 	 Test Loss: 0.46080571
# Test fold 1 	 Epoch [ 18] 	 Train Loss: 0.44796777 	 Val Loss: 0.46362565 	 Test Loss: 0.45985799
# Test fold 1 	 Epoch [ 19] 	 Train Loss: 0.44833773 	 Val Loss: 0.46320676 	 Test Loss: 0.46029034
# Test fold 1 	 Epoch [ 20] 	 Train Loss: 0.44800793 	 Val Loss: 0.46298838 	 Test Loss: 0.46056214
# Test fold 1 	 Epoch [ 21] 	 Train Loss: 0.44827951 	 Val Loss: 0.46259700 	 Test Loss: 0.46114715
# Test fold 1 	 Epoch [ 22] 	 Train Loss: 0.44929864 	 Val Loss: 0.46346985 	 Test Loss: 0.45994863
# Test fold 1 	 Epoch [ 23] 	 Train Loss: 0.44840185 	 Val Loss: 0.46264984 	 Test Loss: 0.46101704
# Test fold 1 	 Epoch [ 24] 	 Train Loss: 0.44770308 	 Val Loss: 0.46326453 	 Test Loss: 0.46017234
# Test fold 1 	 Epoch [ 25] 	 Train Loss: 0.44776229 	 Val Loss: 0.46303481 	 Test Loss: 0.46044073
# Test fold 1 	 Epoch [ 26] 	 Train Loss: 0.44774810 	 Val Loss: 0.46242163 	 Test Loss: 0.46143814
# Test fold 1 	 Epoch [ 27] 	 Train Loss: 0.44802885 	 Val Loss: 0.46345308 	 Test Loss: 0.45995792
# Test fold 1 	 Epoch [ 28] 	 Train Loss: 0.44742750 	 Val Loss: 0.46292510 	 Test Loss: 0.46058201
# Test fold 1 	 Epoch [ 29] 	 Train Loss: 0.44829218 	 Val Loss: 0.46212919 	 Test Loss: 0.46212782
# Test fold 1 	 Epoch [ 30] 	 Train Loss: 0.44831572 	 Val Loss: 0.46224847 	 Test Loss: 0.46181915
# Test fold 1 	 Epoch [ 31] 	 Train Loss: 0.44829200 	 Val Loss: 0.46260622 	 Test Loss: 0.46106241
# Test fold 1 	 Epoch [ 32] 	 Train Loss: 0.44809694 	 Val Loss: 0.46319374 	 Test Loss: 0.46022139
# Test fold 1 	 Epoch [ 33] 	 Train Loss: 0.44805552 	 Val Loss: 0.46296633 	 Test Loss: 0.46051517
# Test fold 1 	 Epoch [ 34] 	 Train Loss: 0.44772658 	 Val Loss: 0.46245212 	 Test Loss: 0.46135212
# Test fold 1 	 Epoch [ 35] 	 Train Loss: 0.44802201 	 Val Loss: 0.46320081 	 Test Loss: 0.46023155
# Test fold 1 	 Epoch [ 36] 	 Train Loss: 0.44772634 	 Val Loss: 0.46304852 	 Test Loss: 0.46042180
# Test fold 1 	 Epoch [ 37] 	 Train Loss: 0.44817712 	 Val Loss: 0.46241416 	 Test Loss: 0.46145562
# Test fold 1 	 Epoch [ 38] 	 Train Loss: 0.44795709 	 Val Loss: 0.46342044 	 Test Loss: 0.45998180
# Test fold 1 	 Epoch [ 39] 	 Train Loss: 0.44781459 	 Val Loss: 0.46257534 	 Test Loss: 0.46111281
# Test fold 1 	 Epoch [ 40] 	 Train Loss: 0.44769515 	 Val Loss: 0.46300910 	 Test Loss: 0.46047210
# Test fold 1 	 Epoch [ 41] 	 Train Loss: 0.44771679 	 Val Loss: 0.46339289 	 Test Loss: 0.46002392
# Test fold 1 	 Epoch [ 42] 	 Train Loss: 0.44773946 	 Val Loss: 0.46303880 	 Test Loss: 0.46043692
# Test fold 1 	 Epoch [ 43] 	 Train Loss: 0.44776587 	 Val Loss: 0.46262100 	 Test Loss: 0.46105551
# Test fold 1 	 Epoch [ 44] 	 Train Loss: 0.44789299 	 Val Loss: 0.46301676 	 Test Loss: 0.46046610
# Test fold 1 	 Epoch [ 45] 	 Train Loss: 0.44774448 	 Val Loss: 0.46252183 	 Test Loss: 0.46122461
# Test fold 1 	 Epoch [ 46] 	 Train Loss: 0.44781744 	 Val Loss: 0.46303635 	 Test Loss: 0.46042767
# Test fold 1 	 Epoch [ 47] 	 Train Loss: 0.44774573 	 Val Loss: 0.46257578 	 Test Loss: 0.46111565
# Test fold 1 	 Epoch [ 48] 	 Train Loss: 0.44832730 	 Val Loss: 0.46318966 	 Test Loss: 0.46023542
# Test fold 1 	 Epoch [ 49] 	 Train Loss: 0.44803993 	 Val Loss: 0.46265594 	 Test Loss: 0.46096146
# Test fold 1 	 Epoch [ 50] 	 Train Loss: 0.44764728 	 Val Loss: 0.46297062 	 Test Loss: 0.46050586
# Test fold 1 	 Epoch [ 51] 	 Train Loss: 0.44781501 	 Val Loss: 0.46360584 	 Test Loss: 0.45978640
# Test fold 1 	 Epoch [ 52] 	 Train Loss: 0.44763697 	 Val Loss: 0.46272744 	 Test Loss: 0.46082314
# Test fold 1 	 Epoch [ 53] 	 Train Loss: 0.44778474 	 Val Loss: 0.46272899 	 Test Loss: 0.46081678
# Test fold 1 	 Epoch [ 54] 	 Train Loss: 0.44765941 	 Val Loss: 0.46301208 	 Test Loss: 0.46041876
# Test fold 1 	 Epoch [ 55] 	 Train Loss: 0.44860704 	 Val Loss: 0.46260048 	 Test Loss: 0.46101531
# Test fold 1 	 Epoch [ 56] 	 Train Loss: 0.44936568 	 Val Loss: 0.46270650 	 Test Loss: 0.46084430
# Test fold 1 	 Epoch [ 57] 	 Train Loss: 0.44751552 	 Val Loss: 0.46281873 	 Test Loss: 0.46066542
# Test fold 1 	 Epoch [ 58] 	 Train Loss: 0.44812003 	 Val Loss: 0.46331655 	 Test Loss: 0.46004519
# Test fold 1 	 Epoch [ 59] 	 Train Loss: 0.44771161 	 Val Loss: 0.46214010 	 Test Loss: 0.46202013
# Test fold 1 	 Epoch [ 60] 	 Train Loss: 0.44749348 	 Val Loss: 0.46278475 	 Test Loss: 0.46075631
# Test fold 1 	 Epoch [ 61] 	 Train Loss: 0.44874112 	 Val Loss: 0.46366824 	 Test Loss: 0.45973405
# Test fold 1 	 Epoch [ 62] 	 Train Loss: 0.44934764 	 Val Loss: 0.46239514 	 Test Loss: 0.46143271
# Test fold 1 	 Epoch [ 63] 	 Train Loss: 0.44744089 	 Val Loss: 0.46315408 	 Test Loss: 0.46027919
# Test fold 1 	 Epoch [ 64] 	 Train Loss: 0.44828015 	 Val Loss: 0.46270437 	 Test Loss: 0.46090652
# Test fold 1 	 Epoch [ 65] 	 Train Loss: 0.44788789 	 Val Loss: 0.46253981 	 Test Loss: 0.46118261
# Test fold 1 	 Epoch [ 66] 	 Train Loss: 0.44768147 	 Val Loss: 0.46297864 	 Test Loss: 0.46050203
# Test fold 1 	 Epoch [ 67] 	 Train Loss: 0.44767317 	 Val Loss: 0.46247898 	 Test Loss: 0.46126882
# Test fold 1 	 Epoch [ 68] 	 Train Loss: 0.44787185 	 Val Loss: 0.46379180 	 Test Loss: 0.45963009
# Test fold 1 	 Epoch [ 69] 	 Train Loss: 0.44805513 	 Val Loss: 0.46259039 	 Test Loss: 0.46105770
# Test fold 1 	 Epoch [ 70] 	 Train Loss: 0.44843138 	 Val Loss: 0.46386743 	 Test Loss: 0.45956290
# Test fold 1 	 Epoch [ 71] 	 Train Loss: 0.44791382 	 Val Loss: 0.46212836 	 Test Loss: 0.46204157
# Test fold 1 	 Epoch [ 72] 	 Train Loss: 0.44776264 	 Val Loss: 0.46261053 	 Test Loss: 0.46102172
# Test fold 1 	 Epoch [ 73] 	 Train Loss: 0.44852276 	 Val Loss: 0.46269634 	 Test Loss: 0.46090647
# Test fold 1 	 Epoch [ 74] 	 Train Loss: 0.44782883 	 Val Loss: 0.46250833 	 Test Loss: 0.46122980
# Test fold 1 	 Epoch [ 75] 	 Train Loss: 0.44769579 	 Val Loss: 0.46311311 	 Test Loss: 0.46032837
# Test fold 1 	 Epoch [ 76] 	 Train Loss: 0.44795259 	 Val Loss: 0.46272583 	 Test Loss: 0.46084958
# Test fold 1 	 Epoch [ 77] 	 Train Loss: 0.44763205 	 Val Loss: 0.46344850 	 Test Loss: 0.45994420
# Test fold 1 	 Epoch [ 78] 	 Train Loss: 0.44797071 	 Val Loss: 0.46320051 	 Test Loss: 0.46021586
# Test fold 1 	 Epoch [ 79] 	 Train Loss: 0.44799512 	 Val Loss: 0.46215924 	 Test Loss: 0.46197223
# Test fold 1 	 Epoch [ 80] 	 Train Loss: 0.44868945 	 Val Loss: 0.46272604 	 Test Loss: 0.46084781
# Test fold 1 	 Epoch [ 81] 	 Train Loss: 0.44759637 	 Val Loss: 0.46239715 	 Test Loss: 0.46141694
# Test fold 1 	 Epoch [ 82] 	 Train Loss: 0.44792661 	 Val Loss: 0.46268384 	 Test Loss: 0.46088950
# Test fold 1 	 Epoch [ 83] 	 Train Loss: 0.44771033 	 Val Loss: 0.46245886 	 Test Loss: 0.46128477
# Test fold 1 	 Epoch [ 84] 	 Train Loss: 0.44788679 	 Val Loss: 0.46320747 	 Test Loss: 0.46020886
# Test fold 1 	 Epoch [ 85] 	 Train Loss: 0.44816713 	 Val Loss: 0.46282353 	 Test Loss: 0.46070253
# Test fold 1 	 Epoch [ 86] 	 Train Loss: 0.44788843 	 Val Loss: 0.46337482 	 Test Loss: 0.46004543
# Test fold 1 	 Epoch [ 87] 	 Train Loss: 0.44763314 	 Val Loss: 0.46237821 	 Test Loss: 0.46148178
# Test fold 1 	 Epoch [ 88] 	 Train Loss: 0.44838241 	 Val Loss: 0.46285547 	 Test Loss: 0.46066653
# Test fold 1 	 Epoch [ 89] 	 Train Loss: 0.44755013 	 Val Loss: 0.46231869 	 Test Loss: 0.46160713
# Test fold 1 	 Epoch [ 90] 	 Train Loss: 0.44807892 	 Val Loss: 0.46301394 	 Test Loss: 0.46044091
# Test fold 1 	 Epoch [ 91] 	 Train Loss: 0.44809174 	 Val Loss: 0.46275279 	 Test Loss: 0.46081049
# Test fold 1 	 Epoch [ 92] 	 Train Loss: 0.44770592 	 Val Loss: 0.46364207 	 Test Loss: 0.45977603
# Test fold 1 	 Epoch [ 93] 	 Train Loss: 0.44753272 	 Val Loss: 0.46291359 	 Test Loss: 0.46057569
# Test fold 1 	 Epoch [ 94] 	 Train Loss: 0.44769440 	 Val Loss: 0.46309265 	 Test Loss: 0.46034269
# Test fold 1 	 Epoch [ 95] 	 Train Loss: 0.44787360 	 Val Loss: 0.46294348 	 Test Loss: 0.46054212
# Test fold 1 	 Epoch [ 96] 	 Train Loss: 0.44755293 	 Val Loss: 0.46269623 	 Test Loss: 0.46089863
# Test fold 1 	 Epoch [ 97] 	 Train Loss: 0.44777454 	 Val Loss: 0.46275308 	 Test Loss: 0.46081076
# Test fold 1 	 Epoch [ 98] 	 Train Loss: 0.44763720 	 Val Loss: 0.46250705 	 Test Loss: 0.46121349
# Test fold 1 	 Epoch [ 99] 	 Train Loss: 0.44823565 	 Val Loss: 0.46308532 	 Test Loss: 0.46037306
# Test fold 1 	 Epoch [100] 	 Train Loss: 0.44771904 	 Val Loss: 0.46276056 	 Test Loss: 0.46080864
# Test fold 1 	 Epoch [101] 	 Train Loss: 0.44839869 	 Val Loss: 0.46228057 	 Test Loss: 0.46171020
# Test fold 1 	 Epoch [102] 	 Train Loss: 0.44806820 	 Val Loss: 0.46209155 	 Test Loss: 0.46221529
# Test fold 1 	 Epoch [103] 	 Train Loss: 0.44761918 	 Val Loss: 0.46295129 	 Test Loss: 0.46059173
# Test fold 1 	 Epoch [104] 	 Train Loss: 0.44754252 	 Val Loss: 0.46324929 	 Test Loss: 0.46023064
# Test fold 1 	 Epoch [105] 	 Train Loss: 0.44775787 	 Val Loss: 0.46353368 	 Test Loss: 0.45992140
# Test fold 1 	 Epoch [106] 	 Train Loss: 0.44792380 	 Val Loss: 0.46294297 	 Test Loss: 0.46060034
# Test fold 1 	 Epoch [107] 	 Train Loss: 0.44763264 	 Val Loss: 0.46295519 	 Test Loss: 0.46057430
# Test fold 1 	 Epoch [108] 	 Train Loss: 0.44778249 	 Val Loss: 0.46345616 	 Test Loss: 0.45998069
# Test fold 1 	 Epoch [109] 	 Train Loss: 0.44769930 	 Val Loss: 0.46266152 	 Test Loss: 0.46098359
# Test fold 1 	 Epoch [110] 	 Train Loss: 0.44799773 	 Val Loss: 0.46219051 	 Test Loss: 0.46192383
# Test fold 1 	 Epoch [111] 	 Train Loss: 0.44836386 	 Val Loss: 0.46290053 	 Test Loss: 0.46062072
# Test fold 1 	 Epoch [112] 	 Train Loss: 0.44770568 	 Val Loss: 0.46280698 	 Test Loss: 0.46078453
# Test fold 1 	 Epoch [113] 	 Train Loss: 0.44804664 	 Val Loss: 0.46268167 	 Test Loss: 0.46097683
# Test fold 1 	 Epoch [114] 	 Train Loss: 0.44775310 	 Val Loss: 0.46279423 	 Test Loss: 0.46079819
# Test fold 1 	 Epoch [115] 	 Train Loss: 0.44786783 	 Val Loss: 0.46297412 	 Test Loss: 0.46054511
# Test fold 1 	 Epoch [116] 	 Train Loss: 0.44817220 	 Val Loss: 0.46257238 	 Test Loss: 0.46115458
# Test fold 1 	 Epoch [117] 	 Train Loss: 0.44802662 	 Val Loss: 0.46312979 	 Test Loss: 0.46036416
# Test fold 1 	 Epoch [118] 	 Train Loss: 0.44799752 	 Val Loss: 0.46255250 	 Test Loss: 0.46120120
# Test fold 1 	 Epoch [119] 	 Train Loss: 0.44797570 	 Val Loss: 0.46271284 	 Test Loss: 0.46092819
# Test fold 1 	 Epoch [120] 	 Train Loss: 0.44810102 	 Val Loss: 0.46334599 	 Test Loss: 0.46010973
# Test fold 1 	 Epoch [121] 	 Train Loss: 0.44765008 	 Val Loss: 0.46292650 	 Test Loss: 0.46060321
# Test fold 1 	 Epoch [122] 	 Train Loss: 0.44754040 	 Val Loss: 0.46319206 	 Test Loss: 0.46026567
# Test fold 1 	 Epoch [123] 	 Train Loss: 0.44763946 	 Val Loss: 0.46257824 	 Test Loss: 0.46111088
# Test fold 1 	 Epoch [124] 	 Train Loss: 0.44775117 	 Val Loss: 0.46305829 	 Test Loss: 0.46041193
# Test fold 1 	 Epoch [125] 	 Train Loss: 0.44770502 	 Val Loss: 0.46286622 	 Test Loss: 0.46065760
# Test fold 1 	 Epoch [126] 	 Train Loss: 0.44848636 	 Val Loss: 0.46298602 	 Test Loss: 0.46049761
# Test fold 1 	 Epoch [127] 	 Train Loss: 0.44814831 	 Val Loss: 0.46330957 	 Test Loss: 0.46011038
# Test fold 1 	 Epoch [128] 	 Train Loss: 0.44764131 	 Val Loss: 0.46285003 	 Test Loss: 0.46066240
# Test fold 1 	 Epoch [129] 	 Train Loss: 0.44813713 	 Val Loss: 0.46306395 	 Test Loss: 0.46038516
# Test fold 1 	 Epoch [130] 	 Train Loss: 0.44776392 	 Val Loss: 0.46300852 	 Test Loss: 0.46044682
# Test fold 1 	 Epoch [131] 	 Train Loss: 0.44756682 	 Val Loss: 0.46271778 	 Test Loss: 0.46085053
# Test fold 1 	 Epoch [132] 	 Train Loss: 0.44785236 	 Val Loss: 0.46290771 	 Test Loss: 0.46058999
# Test fold 1 	 Epoch [133] 	 Train Loss: 0.44765120 	 Val Loss: 0.46341683 	 Test Loss: 0.45999951
# Test fold 1 	 Epoch [134] 	 Train Loss: 0.44761892 	 Val Loss: 0.46272787 	 Test Loss: 0.46086188
# Test fold 1 	 Epoch [135] 	 Train Loss: 0.44768829 	 Val Loss: 0.46284781 	 Test Loss: 0.46068338
# Test fold 1 	 Epoch [136] 	 Train Loss: 0.44761930 	 Val Loss: 0.46281501 	 Test Loss: 0.46074071
# Test fold 1 	 Epoch [137] 	 Train Loss: 0.44831166 	 Val Loss: 0.46312066 	 Test Loss: 0.46033507
# Test fold 1 	 Epoch [138] 	 Train Loss: 0.44822523 	 Val Loss: 0.46312442 	 Test Loss: 0.46032208
# Test fold 1 	 Epoch [139] 	 Train Loss: 0.44767866 	 Val Loss: 0.46272032 	 Test Loss: 0.46085485
# Test fold 1 	 Epoch [140] 	 Train Loss: 0.44778748 	 Val Loss: 0.46275939 	 Test Loss: 0.46077096
# Test fold 1 	 Epoch [141] 	 Train Loss: 0.44783352 	 Val Loss: 0.46334152 	 Test Loss: 0.46004059
# Test fold 1 	 Epoch [142] 	 Train Loss: 0.44797895 	 Val Loss: 0.46283088 	 Test Loss: 0.46068015
# Test fold 1 	 Epoch [143] 	 Train Loss: 0.44763754 	 Val Loss: 0.46295755 	 Test Loss: 0.46050806
# Test fold 1 	 Epoch [144] 	 Train Loss: 0.44780840 	 Val Loss: 0.46314658 	 Test Loss: 0.46028595
# Test fold 1 	 Epoch [145] 	 Train Loss: 0.44755896 	 Val Loss: 0.46247105 	 Test Loss: 0.46126961
# Test fold 1 	 Epoch [146] 	 Train Loss: 0.44784523 	 Val Loss: 0.46251678 	 Test Loss: 0.46118793
# Test fold 1 	 Epoch [147] 	 Train Loss: 0.44801643 	 Val Loss: 0.46362976 	 Test Loss: 0.45978010
# Test fold 1 	 Epoch [148] 	 Train Loss: 0.44768253 	 Val Loss: 0.46246861 	 Test Loss: 0.46124378
# Test fold 1 	 Epoch [149] 	 Train Loss: 0.44836414 	 Val Loss: 0.46281418 	 Test Loss: 0.46068949
# Test fold 1 	 Epoch [150] 	 Train Loss: 0.44792347 	 Val Loss: 0.46253667 	 Test Loss: 0.46111835
# Test fold 1 	 Epoch [151] 	 Train Loss: 0.44757744 	 Val Loss: 0.46300858 	 Test Loss: 0.46041812
# Test fold 1 	 Epoch [152] 	 Train Loss: 0.44765161 	 Val Loss: 0.46345794 	 Test Loss: 0.45991591
# Early stopping triggered after 153 epochs.
