# %%
import pandas as pd
import lzma
import torch
import torch.nn as nn
import numpy as np
import random
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

# %%
dataset = 'detailed'
test_fold = 1

nonlinearity='relu'
hidden_size = 16
num_layers = 2

max_epoch = 1000
patience = 50

# %%
# Hinged Square Loss
class SquaredHingeLoss(nn.Module):
    def __init__(self, margin=1):
        super(SquaredHingeLoss, self).__init__()
        self.margin = margin

    def forward(self, predicted, y):
        low, high = y[:, 0:1], y[:, 1:2]
        loss_low = torch.relu(low - predicted + self.margin)
        loss_high = torch.relu(predicted - high + self.margin)
        loss = loss_low + loss_high
        return torch.mean(torch.square(loss))

# %%
# Define the RNN model
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, nonlinearity=nonlinearity)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x, lengths):
        # x is PackedSequence
        packed_output, hidden = self.rnn(x)
        # Get the last hidden state from the last layer
        last_hidden = hidden[-1]  # Shape: (batch_size, hidden_size)
        x = self.fc(last_hidden)
        x = torch.relu(x + 10) - torch.relu(x - 10) - 10
        return x

# %%
# Custom Dataset
class SequenceDataset(torch.utils.data.Dataset):
    def __init__(self, sequences, targets):
        self.sequences = sequences
        self.targets = targets

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        return self.sequences[idx], self.targets[idx]

# %%
# Collate function for DataLoader
def collate_fn(batch):
    sequences, targets = zip(*batch)
    # Get lengths of each sequence
    lengths = torch.tensor([len(seq) for seq in sequences], dtype=torch.long)
    # Pad sequences to the same length
    sequences_padded = torch.nn.utils.rnn.pad_sequence(sequences, batch_first=True)
    # Stack targets
    targets = torch.stack(targets)
    return sequences_padded.unsqueeze(-1), targets, lengths

# %%
# Function to compute loss value
def get_loss_value(model, data_loader, criterion):
    model.eval()
    total_loss = 0
    total_samples = 0
    with torch.no_grad():
        for seq_inputs, targets, lengths in data_loader:
            seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
            outputs = model(seq_inputs_packed, lengths)
            loss = criterion(outputs, targets.unsqueeze(-1))
            batch_size = seq_inputs.size(0)
            total_loss += loss.item() * batch_size
            total_samples += batch_size
    average_loss = total_loss / total_samples
    return average_loss

# %%
# Function to test the model
def test_model(model, data_loader):
    model.eval()
    predictions = []
    with torch.no_grad():
        for seq_inputs, _, lengths in data_loader:
            seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
            outputs = model(seq_inputs_packed, lengths)
            predictions.extend(outputs.squeeze(-1).tolist())
    return predictions

# %%
# Load data
file_path = f'../../sequence_data/{dataset}/profiles.csv.xz'
with lzma.open(file_path, 'rt') as file:
    signal_df = pd.read_csv(file)

seqs = tuple(signal_df.groupby('sequenceID'))

# Load data
folds_df = pd.read_csv(f'../../training_data/{dataset}/folds.csv')
target_df = pd.read_csv(f'../../training_data/{dataset}/target.csv')

# Split data into training and test sets
train_ids = folds_df[folds_df['fold'] != test_fold]['sequenceID']
test_ids = folds_df[folds_df['fold'] == test_fold]['sequenceID']

# Train sequences
train_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(train_ids)]

# Test sequences
test_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(test_ids)]

# Targets
target_df_train = target_df[target_df['sequenceID'].isin(train_ids)]
target_df_test = target_df[target_df['sequenceID'].isin(test_ids)]
y_train = torch.tensor(target_df_train.iloc[:, 1:].to_numpy(), dtype=torch.float32)
y_test = torch.tensor(target_df_test.iloc[:, 1:].to_numpy(), dtype=torch.float32)

# Split train into subtrain and validation (80% subtrain, 20% validation)
train_seqs, val_seqs, y_train, y_val = train_test_split(train_seqs, y_train, test_size=0.2, random_state=42)

# Create datasets and dataloaders
batch_size = 64

train_dataset = SequenceDataset(train_seqs, y_train)
val_dataset = SequenceDataset(val_seqs, y_val)
test_dataset = SequenceDataset(test_seqs, y_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

# %%
# Initialize the model, loss function, and optimizer
model = RNNModel(1, hidden_size, num_layers)
criterion = SquaredHingeLoss()
optimizer = torch.optim.Adam(model.parameters())

# Initialize variables for best validation loss and best model
best_val_loss = float('inf')    # Set best validation loss to infinity initially
patience_counter = 0            # Counter for early stopping
best_model_state = None         # Variable to store the best model parameters

# Training loop
for epoch in range(max_epoch):
    model.train()
    total_loss = 0
    total_samples = 0

    for seq_inputs, targets, lengths in train_loader:
        optimizer.zero_grad()
        seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
        outputs = model(seq_inputs_packed, lengths)
        loss = criterion(outputs, targets.unsqueeze(-1))

        # Stop training if loss is NaN
        if torch.isnan(loss):
            print(f'Stopping training at epoch {epoch} due to NaN loss.')
            break

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        batch_size = seq_inputs.size(0)
        total_loss += loss.item() * batch_size
        total_samples += batch_size

    # Calculate average loss for this epoch (training)
    average_loss = total_loss / total_samples

    # Validation step
    average_val_loss  = get_loss_value(model, val_loader, criterion)
    average_test_loss = get_loss_value(model, test_loader, criterion)

    if epoch % 1 == 0:
        print(f'Test fold {test_fold} \t Epoch [{epoch:3d}] \t Train Loss: {average_loss:.8f} \t Val Loss: {average_val_loss:.8f} \t Test Loss: {average_test_loss:.8f}')

    # Early stopping logic based on validation loss
    if average_val_loss < best_val_loss:
        best_val_loss = average_val_loss  # Update best validation loss
        patience_counter = 0  # Reset patience counter

        # Save the best model parameters in memory
        best_model_state = model.state_dict()  # Store the model parameters
    else:
        patience_counter += 1  # Increment patience counter

    # Stop training if patience is exceeded or NaN is detected
    if patience_counter >= patience or torch.isnan(loss):
        if torch.isnan(loss):
            print(f'Training stopped due to NaN loss at epoch {epoch}.')
        else:
            print(f'Early stopping triggered after {epoch + 1} epochs.')
        break

# After training, you can restore the best model parameters if needed
if best_model_state is not None:
    model.load_state_dict(best_model_state)
    model.eval()  # Set the model to evaluation mode

# Test the model and collect outputs
pred_lldas = test_model(model, test_loader)

# Save to CSV
lldas_df = pd.DataFrame(list(zip(test_ids, pred_lldas)), columns=['sequenceID', 'llda'])
lldas_df.to_csv(f'predictions/proposed.{dataset}.{hidden_size}.{num_layers}.{nonlinearity}.{patience}.{test_fold}.csv', index=False)
# Out:
# Test fold 1 	 Epoch [  0] 	 Train Loss: 0.48384993 	 Val Loss: 0.47540801 	 Test Loss: 0.45942624
# Test fold 1 	 Epoch [  1] 	 Train Loss: 0.44844187 	 Val Loss: 0.46252799 	 Test Loss: 0.46144144
# Test fold 1 	 Epoch [  2] 	 Train Loss: 0.44791258 	 Val Loss: 0.46315140 	 Test Loss: 0.46053171
# Test fold 1 	 Epoch [  3] 	 Train Loss: 0.44822470 	 Val Loss: 0.46218324 	 Test Loss: 0.46212122
# Test fold 1 	 Epoch [  4] 	 Train Loss: 0.44922738 	 Val Loss: 0.46268925 	 Test Loss: 0.46118780
# Test fold 1 	 Epoch [  5] 	 Train Loss: 0.44959025 	 Val Loss: 0.46520050 	 Test Loss: 0.45904396
# Test fold 1 	 Epoch [  6] 	 Train Loss: 0.44830180 	 Val Loss: 0.46225859 	 Test Loss: 0.46201826
# Test fold 1 	 Epoch [  7] 	 Train Loss: 0.44819094 	 Val Loss: 0.46255852 	 Test Loss: 0.46137053
# Test fold 1 	 Epoch [  8] 	 Train Loss: 0.44832266 	 Val Loss: 0.46241718 	 Test Loss: 0.46169603
# Test fold 1 	 Epoch [  9] 	 Train Loss: 0.44776946 	 Val Loss: 0.46313396 	 Test Loss: 0.46062361
# Test fold 1 	 Epoch [ 10] 	 Train Loss: 0.44955410 	 Val Loss: 0.46291887 	 Test Loss: 0.46081506
# Test fold 1 	 Epoch [ 11] 	 Train Loss: 0.44927278 	 Val Loss: 0.46366566 	 Test Loss: 0.46009773
# Test fold 1 	 Epoch [ 12] 	 Train Loss: 0.44802857 	 Val Loss: 0.46256379 	 Test Loss: 0.46138095
# Test fold 1 	 Epoch [ 13] 	 Train Loss: 0.44765532 	 Val Loss: 0.46228392 	 Test Loss: 0.46188483
# Test fold 1 	 Epoch [ 14] 	 Train Loss: 0.44834283 	 Val Loss: 0.46423326 	 Test Loss: 0.45952161
# Test fold 1 	 Epoch [ 15] 	 Train Loss: 0.44937850 	 Val Loss: 0.46236232 	 Test Loss: 0.46160186
# Test fold 1 	 Epoch [ 16] 	 Train Loss: 0.44824417 	 Val Loss: 0.46348726 	 Test Loss: 0.46019257
# Test fold 1 	 Epoch [ 17] 	 Train Loss: 0.44759326 	 Val Loss: 0.46236245 	 Test Loss: 0.46169138
# Test fold 1 	 Epoch [ 18] 	 Train Loss: 0.44801300 	 Val Loss: 0.46234262 	 Test Loss: 0.46167961
# Test fold 1 	 Epoch [ 19] 	 Train Loss: 0.44816024 	 Val Loss: 0.46263486 	 Test Loss: 0.46110886
# Test fold 1 	 Epoch [ 20] 	 Train Loss: 0.45023427 	 Val Loss: 0.46388021 	 Test Loss: 0.45979506
# Test fold 1 	 Epoch [ 21] 	 Train Loss: 0.44743659 	 Val Loss: 0.46213075 	 Test Loss: 0.46225491
# Test fold 1 	 Epoch [ 22] 	 Train Loss: 0.44809217 	 Val Loss: 0.46247003 	 Test Loss: 0.46154433
# Test fold 1 	 Epoch [ 23] 	 Train Loss: 0.44786184 	 Val Loss: 0.46216055 	 Test Loss: 0.46219629
# Test fold 1 	 Epoch [ 24] 	 Train Loss: 0.44811066 	 Val Loss: 0.46304369 	 Test Loss: 0.46066556
# Test fold 1 	 Epoch [ 25] 	 Train Loss: 0.44780422 	 Val Loss: 0.46346366 	 Test Loss: 0.46024957
# Test fold 1 	 Epoch [ 26] 	 Train Loss: 0.44791073 	 Val Loss: 0.46292585 	 Test Loss: 0.46082924
# Test fold 1 	 Epoch [ 27] 	 Train Loss: 0.44764850 	 Val Loss: 0.46289104 	 Test Loss: 0.46084147
# Test fold 1 	 Epoch [ 28] 	 Train Loss: 0.44840129 	 Val Loss: 0.46270540 	 Test Loss: 0.46106997
# Test fold 1 	 Epoch [ 29] 	 Train Loss: 0.44778203 	 Val Loss: 0.46435579 	 Test Loss: 0.45947626
# Test fold 1 	 Epoch [ 30] 	 Train Loss: 0.44799850 	 Val Loss: 0.46316529 	 Test Loss: 0.46050202
# Test fold 1 	 Epoch [ 31] 	 Train Loss: 0.44835205 	 Val Loss: 0.46255786 	 Test Loss: 0.46132990
# Test fold 1 	 Epoch [ 32] 	 Train Loss: 0.44876547 	 Val Loss: 0.46347204 	 Test Loss: 0.46016927
# Test fold 1 	 Epoch [ 33] 	 Train Loss: 0.44789268 	 Val Loss: 0.46320785 	 Test Loss: 0.46041051
# Test fold 1 	 Epoch [ 34] 	 Train Loss: 0.44874456 	 Val Loss: 0.46252370 	 Test Loss: 0.46138621
# Test fold 1 	 Epoch [ 35] 	 Train Loss: 0.44771070 	 Val Loss: 0.46350475 	 Test Loss: 0.46004390
# Test fold 1 	 Epoch [ 36] 	 Train Loss: 0.44844138 	 Val Loss: 0.46231838 	 Test Loss: 0.46161964
# Test fold 1 	 Epoch [ 37] 	 Train Loss: 0.44841321 	 Val Loss: 0.46398625 	 Test Loss: 0.45965487
# Test fold 1 	 Epoch [ 38] 	 Train Loss: 0.44879952 	 Val Loss: 0.46184829 	 Test Loss: 0.46284585
# Test fold 1 	 Epoch [ 39] 	 Train Loss: 0.44978680 	 Val Loss: 0.46486557 	 Test Loss: 0.45909014
# Test fold 1 	 Epoch [ 40] 	 Train Loss: 0.44831646 	 Val Loss: 0.46293504 	 Test Loss: 0.46065275
# Test fold 1 	 Epoch [ 41] 	 Train Loss: 0.44773358 	 Val Loss: 0.46275796 	 Test Loss: 0.46087112
# Test fold 1 	 Epoch [ 42] 	 Train Loss: 0.44794273 	 Val Loss: 0.46277652 	 Test Loss: 0.46085254
# Test fold 1 	 Epoch [ 43] 	 Train Loss: 0.44818693 	 Val Loss: 0.46379259 	 Test Loss: 0.45977171
# Test fold 1 	 Epoch [ 44] 	 Train Loss: 0.44850728 	 Val Loss: 0.46234280 	 Test Loss: 0.46155382
# Test fold 1 	 Epoch [ 45] 	 Train Loss: 0.44754255 	 Val Loss: 0.46264123 	 Test Loss: 0.46104854
# Test fold 1 	 Epoch [ 46] 	 Train Loss: 0.44869672 	 Val Loss: 0.46264392 	 Test Loss: 0.46113161
# Test fold 1 	 Epoch [ 47] 	 Train Loss: 0.44777854 	 Val Loss: 0.46309599 	 Test Loss: 0.46051254
# Test fold 1 	 Epoch [ 48] 	 Train Loss: 0.44882495 	 Val Loss: 0.46352497 	 Test Loss: 0.46001383
# Test fold 1 	 Epoch [ 49] 	 Train Loss: 0.44818751 	 Val Loss: 0.46374009 	 Test Loss: 0.45988696
# Test fold 1 	 Epoch [ 50] 	 Train Loss: 0.44840403 	 Val Loss: 0.46318655 	 Test Loss: 0.46041149
# Test fold 1 	 Epoch [ 51] 	 Train Loss: 0.44775049 	 Val Loss: 0.46321944 	 Test Loss: 0.46034095
# Test fold 1 	 Epoch [ 52] 	 Train Loss: 0.44755866 	 Val Loss: 0.46336394 	 Test Loss: 0.46017516
# Test fold 1 	 Epoch [ 53] 	 Train Loss: 0.44768362 	 Val Loss: 0.46272460 	 Test Loss: 0.46094839
# Test fold 1 	 Epoch [ 54] 	 Train Loss: 0.44834147 	 Val Loss: 0.46340812 	 Test Loss: 0.46016706
# Test fold 1 	 Epoch [ 55] 	 Train Loss: 0.44821812 	 Val Loss: 0.46372208 	 Test Loss: 0.45992611
# Test fold 1 	 Epoch [ 56] 	 Train Loss: 0.44772491 	 Val Loss: 0.46269238 	 Test Loss: 0.46109544
# Test fold 1 	 Epoch [ 57] 	 Train Loss: 0.44826969 	 Val Loss: 0.46257963 	 Test Loss: 0.46127464
# Test fold 1 	 Epoch [ 58] 	 Train Loss: 0.44823805 	 Val Loss: 0.46349584 	 Test Loss: 0.46006791
# Test fold 1 	 Epoch [ 59] 	 Train Loss: 0.44841901 	 Val Loss: 0.46407285 	 Test Loss: 0.45962449
# Test fold 1 	 Epoch [ 60] 	 Train Loss: 0.44794369 	 Val Loss: 0.46256149 	 Test Loss: 0.46122097
# Test fold 1 	 Epoch [ 61] 	 Train Loss: 0.44776432 	 Val Loss: 0.46311979 	 Test Loss: 0.46046098
# Test fold 1 	 Epoch [ 62] 	 Train Loss: 0.44812090 	 Val Loss: 0.46252330 	 Test Loss: 0.46132380
# Test fold 1 	 Epoch [ 63] 	 Train Loss: 0.44771602 	 Val Loss: 0.46272146 	 Test Loss: 0.46100683
# Test fold 1 	 Epoch [ 64] 	 Train Loss: 0.44782472 	 Val Loss: 0.46255821 	 Test Loss: 0.46125630
# Test fold 1 	 Epoch [ 65] 	 Train Loss: 0.44817038 	 Val Loss: 0.46290571 	 Test Loss: 0.46074954
# Test fold 1 	 Epoch [ 66] 	 Train Loss: 0.44772030 	 Val Loss: 0.46221696 	 Test Loss: 0.46192973
# Test fold 1 	 Epoch [ 67] 	 Train Loss: 0.44763421 	 Val Loss: 0.46357381 	 Test Loss: 0.45999365
# Test fold 1 	 Epoch [ 68] 	 Train Loss: 0.44963067 	 Val Loss: 0.46368468 	 Test Loss: 0.45989428
# Test fold 1 	 Epoch [ 69] 	 Train Loss: 0.44781259 	 Val Loss: 0.46258265 	 Test Loss: 0.46122074
# Test fold 1 	 Epoch [ 70] 	 Train Loss: 0.44769341 	 Val Loss: 0.46314296 	 Test Loss: 0.46044375
# Test fold 1 	 Epoch [ 71] 	 Train Loss: 0.44841756 	 Val Loss: 0.46260192 	 Test Loss: 0.46117097
# Test fold 1 	 Epoch [ 72] 	 Train Loss: 0.44800586 	 Val Loss: 0.46426037 	 Test Loss: 0.45948566
# Test fold 1 	 Epoch [ 73] 	 Train Loss: 0.44848852 	 Val Loss: 0.46203350 	 Test Loss: 0.46242732
# Test fold 1 	 Epoch [ 74] 	 Train Loss: 0.44828301 	 Val Loss: 0.46300926 	 Test Loss: 0.46059087
# Test fold 1 	 Epoch [ 75] 	 Train Loss: 0.44792667 	 Val Loss: 0.46296191 	 Test Loss: 0.46067369
# Test fold 1 	 Epoch [ 76] 	 Train Loss: 0.44795097 	 Val Loss: 0.46351845 	 Test Loss: 0.46004661
# Test fold 1 	 Epoch [ 77] 	 Train Loss: 0.44808761 	 Val Loss: 0.46275751 	 Test Loss: 0.46087336
# Test fold 1 	 Epoch [ 78] 	 Train Loss: 0.44832648 	 Val Loss: 0.46315254 	 Test Loss: 0.46040999
# Test fold 1 	 Epoch [ 79] 	 Train Loss: 0.44768964 	 Val Loss: 0.46290120 	 Test Loss: 0.46071627
# Test fold 1 	 Epoch [ 80] 	 Train Loss: 0.44758342 	 Val Loss: 0.46328996 	 Test Loss: 0.46023061
# Test fold 1 	 Epoch [ 81] 	 Train Loss: 0.44761105 	 Val Loss: 0.46275406 	 Test Loss: 0.46091920
# Test fold 1 	 Epoch [ 82] 	 Train Loss: 0.44768788 	 Val Loss: 0.46293148 	 Test Loss: 0.46064320
# Test fold 1 	 Epoch [ 83] 	 Train Loss: 0.44831312 	 Val Loss: 0.46315816 	 Test Loss: 0.46041465
# Test fold 1 	 Epoch [ 84] 	 Train Loss: 0.44791588 	 Val Loss: 0.46389023 	 Test Loss: 0.45975445
# Test fold 1 	 Epoch [ 85] 	 Train Loss: 0.44750676 	 Val Loss: 0.46238471 	 Test Loss: 0.46157280
# Test fold 1 	 Epoch [ 86] 	 Train Loss: 0.44772417 	 Val Loss: 0.46292721 	 Test Loss: 0.46068280
# Test fold 1 	 Epoch [ 87] 	 Train Loss: 0.44765601 	 Val Loss: 0.46296493 	 Test Loss: 0.46062099
# Test fold 1 	 Epoch [ 88] 	 Train Loss: 0.44758076 	 Val Loss: 0.46266561 	 Test Loss: 0.46101970
# Early stopping triggered after 89 epochs.
