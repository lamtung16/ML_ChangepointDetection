# %%
import pandas as pd
import lzma
import torch
import torch.nn as nn
import numpy as np
import random

# %%
dataset = 'systematic'

# %%
# Hinged Square Loss
class SquaredHingeLoss(nn.Module):
    def __init__(self, margin=1):
        super(SquaredHingeLoss, self).__init__()
        self.margin = margin

    def forward(self, predicted, y):
        low, high = y[:, 0:1], y[:, 1:2]
        loss_low = torch.relu(low - predicted + self.margin)
        loss_high = torch.relu(predicted - high + self.margin)
        loss = loss_low + loss_high
        return torch.mean(torch.square(loss))

# %%
# Define the LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)  # Output layer

    def forward(self, x):               # x shape: (batch_size, seq_length, input_size)
        lstm_out, _ = self.lstm(x)      # lstm_out shape: (batch_size, seq_length, hidden_size)
        last_out = lstm_out[:, -1, :]   # last_out shape: (batch_size, hidden_size)
        x = self.fc(last_out)           # x shape: (batch_size, 1)
        x = 7 * torch.tanh(x)           # Apply 7 * tanh() to the output
        return x

# %%
# Function to test the model
def test_model(model, inputs):
    model.eval()
    predictions = []

    with torch.no_grad():
        for seq_input in inputs:
            seq_input = seq_input.unsqueeze(0).unsqueeze(-1)
            output_seq = model(seq_input)
            predictions.append(output_seq.item())

    return predictions

# %%
file_path = f'../../sequence_data/{dataset}/profiles.csv.xz'
with lzma.open(file_path, 'rt') as file:
    signal_df = pd.read_csv(file)

seqs = tuple(signal_df.groupby('sequenceID'))

# %%
# Load data
folds_df = pd.read_csv(f'../../training_data/{dataset}/folds.csv')
target_df = pd.read_csv(f'../../training_data/{dataset}/target.csv')

for test_fold in range(1, np.unique(folds_df['fold']).__len__() + 1):
    # Split data into training and test sets
    train_ids = folds_df[folds_df['fold'] != test_fold]['sequenceID']
    test_ids = folds_df[folds_df['fold'] == test_fold]['sequenceID']

    # train sequences
    train_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(train_ids)]

    # test sequences
    test_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(test_ids)]
    
    # train target
    target_df_train = target_df[target_df['sequenceID'].isin(train_ids)]
    y_train = torch.tensor(target_df_train.iloc[:, 1:].to_numpy())

    # Initialize the model, loss function, and optimizer
    model = LSTMModel(1, 16, 2)
    criterion = SquaredHingeLoss()
    optimizer = torch.optim.Adam(model.parameters())

    # Initialize variables for best loss and best model
    best_loss = float('inf')    # Set best_loss to infinity initially
    patience_counter = 0        # Counter for early stopping
    patience = 50               # Number of epochs to wait for improvement before stopping
    best_model_state = None     # Variable to store the best model parameters

    # Training loop
    for epoch in range(1000):
        combined = list(zip(train_seqs, y_train))   # Combine sequences and targets
        random.shuffle(combined)                    # Shuffle both train_seqs and y_train together
        train_seqs, y_train = zip(*combined)        # Unzip them back into separate lists

        total_loss = 0
        nan_flag = False  # Flag to detect NaN loss

        for i, seq_input in enumerate(train_seqs):
            # Prepare input and target for the current sequence
            target = y_train[i].unsqueeze(0)  # Get the corresponding target for the sequence

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            seq_input = seq_input.unsqueeze(0).unsqueeze(-1)  # Shape: (1, seq_length, input_size)
            output_seq = model(seq_input)                     # Get model output for the sequence
            loss = criterion(output_seq, target.unsqueeze(-1))  # Calculate loss

            # Check for NaN loss
            if torch.isnan(loss).any():
                print(f"NaN loss detected at Epoch [{epoch}], Step [{i}]. Saving model before NaN occurred.")
                torch.save(best_model_state, 'model_before_nan.pth')  # Save model state before NaN loss
                nan_flag = True
                break  # Exit the training loop if NaN is encountered

            # Backward pass and optimize
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        if nan_flag:
            break  # Stop training if NaN was encountered

        # Calculate average loss for this epoch
        average_loss = total_loss / len(train_seqs)
        if epoch % 10 == 0:
            print(f'Test fold {test_fold}, Epoch [{epoch}], Average Loss: {average_loss:.8f}')

        # Early stopping logic
        if average_loss < best_loss:
            best_loss = average_loss  # Update best loss
            patience_counter = 0  # Reset patience counter

            # Save the best model parameters in memory
            best_model_state = model.state_dict()  # Store the model parameters
        else:
            patience_counter += 1  # Increment patience counter

        # Stop training if patience is exceeded
        if patience_counter >= patience:
            print(f'Early stopping triggered after {epoch + 1} epochs.')
            break
    
    # After training, you can restore the best model parameters if needed
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        model.eval()  # Set the model to evaluation mode
    
    # Test the model and collect outputs
    pred_lldas = test_model(model, test_seqs)

    # Save to CSV
    lldas_df = pd.DataFrame(list(zip(test_ids, pred_lldas)), columns=['sequenceID', 'llda'])
    lldas_df.to_csv(f'predictions/proposed.{dataset}.{test_fold}.csv', index=False)
# Out:
# Test fold 1, Epoch [0], Average Loss: 0.27619120
# Test fold 1, Epoch [10], Average Loss: 0.16228910
# Test fold 1, Epoch [20], Average Loss: 0.12545261
# Test fold 1, Epoch [30], Average Loss: 0.11050702
# Test fold 1, Epoch [40], Average Loss: 0.10567840
# Test fold 1, Epoch [50], Average Loss: 0.09535194
# Test fold 1, Epoch [60], Average Loss: 0.07738361
# Test fold 1, Epoch [70], Average Loss: 0.08457083
# Test fold 1, Epoch [80], Average Loss: 0.07769794
# Test fold 1, Epoch [90], Average Loss: 0.08066082
# NaN loss detected at Epoch [96], Step [1425]. Saving model before NaN occurred.
# Test fold 2, Epoch [0], Average Loss: 0.27948191
# Test fold 2, Epoch [10], Average Loss: 0.15858191
# Test fold 2, Epoch [20], Average Loss: 0.12307802
# Test fold 2, Epoch [30], Average Loss: 0.10888695
# Test fold 2, Epoch [40], Average Loss: 0.09617798
# Test fold 2, Epoch [50], Average Loss: 0.08346634
# Test fold 2, Epoch [60], Average Loss: 0.06823051
# Test fold 2, Epoch [70], Average Loss: 0.05184791
# Test fold 2, Epoch [80], Average Loss: 0.03212633
# Test fold 2, Epoch [90], Average Loss: 0.02098842
# Test fold 2, Epoch [100], Average Loss: 0.01672454
# Test fold 2, Epoch [110], Average Loss: 0.01735533
# Test fold 2, Epoch [120], Average Loss: 0.02278111
# Test fold 2, Epoch [130], Average Loss: 0.01965467
# Test fold 2, Epoch [140], Average Loss: 0.00698192
# Test fold 2, Epoch [150], Average Loss: 0.00483675
# Test fold 2, Epoch [160], Average Loss: 0.00980855
# Test fold 2, Epoch [170], Average Loss: 0.00448095
# Test fold 2, Epoch [180], Average Loss: 0.01155996
# Test fold 2, Epoch [190], Average Loss: 0.00811170
# Test fold 2, Epoch [200], Average Loss: 0.00463169
# Test fold 2, Epoch [210], Average Loss: 0.00628760
# Test fold 2, Epoch [220], Average Loss: 0.00485553
# Test fold 2, Epoch [230], Average Loss: 0.00219154
# Test fold 2, Epoch [240], Average Loss: 0.00167056
# Test fold 2, Epoch [250], Average Loss: 0.00256268
# Test fold 2, Epoch [260], Average Loss: 0.00353682
# Test fold 2, Epoch [270], Average Loss: 0.00197750
# Test fold 2, Epoch [280], Average Loss: 0.00164120
# Early stopping triggered after 289 epochs.
# Test fold 3, Epoch [0], Average Loss: 0.29169971
# Test fold 3, Epoch [10], Average Loss: 0.17394929
# Test fold 3, Epoch [20], Average Loss: 0.11655804
# Test fold 3, Epoch [30], Average Loss: 0.10812124
# Test fold 3, Epoch [40], Average Loss: 0.08638566
# Test fold 3, Epoch [50], Average Loss: 0.07342682
# Test fold 3, Epoch [60], Average Loss: 0.06749761
# Test fold 3, Epoch [70], Average Loss: 0.05084918
# Test fold 3, Epoch [80], Average Loss: 0.04166808
# Test fold 3, Epoch [90], Average Loss: 0.02988752
# Test fold 3, Epoch [100], Average Loss: 0.02133221
# Test fold 3, Epoch [110], Average Loss: 0.01885452
# Test fold 3, Epoch [120], Average Loss: 0.01186499
# Test fold 3, Epoch [130], Average Loss: 0.01352261
# Test fold 3, Epoch [140], Average Loss: 0.00798018
# Test fold 3, Epoch [150], Average Loss: 0.00870117
# Test fold 3, Epoch [160], Average Loss: 0.00796495
# Test fold 3, Epoch [170], Average Loss: 0.00808211
# Test fold 3, Epoch [180], Average Loss: 0.00644460
# Test fold 3, Epoch [190], Average Loss: 0.00341866
# Test fold 3, Epoch [200], Average Loss: 0.00327308
# Test fold 3, Epoch [210], Average Loss: 0.00775072
# Test fold 3, Epoch [220], Average Loss: 0.00385173
# Test fold 3, Epoch [230], Average Loss: 0.00121462
# Test fold 3, Epoch [240], Average Loss: 0.00374276
# Test fold 3, Epoch [250], Average Loss: 0.00123331
# Test fold 3, Epoch [260], Average Loss: 0.00671651
# Test fold 3, Epoch [270], Average Loss: 0.00375824
# Test fold 3, Epoch [280], Average Loss: 0.00309412
# Test fold 3, Epoch [290], Average Loss: 0.00292981
# Test fold 3, Epoch [300], Average Loss: 0.00505291
# Test fold 3, Epoch [310], Average Loss: 0.00304422
# Test fold 3, Epoch [320], Average Loss: 0.00858121
# Early stopping triggered after 328 epochs.
# Test fold 4, Epoch [0], Average Loss: 0.28355115
# Test fold 4, Epoch [10], Average Loss: 0.22297969
# Test fold 4, Epoch [20], Average Loss: 0.19889736
# Test fold 4, Epoch [30], Average Loss: 0.17319224
# Test fold 4, Epoch [40], Average Loss: 0.15999968
# Test fold 4, Epoch [50], Average Loss: 0.10774243
# Test fold 4, Epoch [60], Average Loss: 0.08314984
# Test fold 4, Epoch [70], Average Loss: 0.07634650
# Test fold 4, Epoch [80], Average Loss: 0.06852241
# Test fold 4, Epoch [90], Average Loss: 0.05439483
# Test fold 4, Epoch [100], Average Loss: 0.04228876
# Test fold 4, Epoch [110], Average Loss: 0.03048011
# Test fold 4, Epoch [120], Average Loss: 0.02637646
# Test fold 4, Epoch [130], Average Loss: 0.01627375
# Test fold 4, Epoch [140], Average Loss: 0.01000704
# Test fold 4, Epoch [150], Average Loss: 0.00782998
# Test fold 4, Epoch [160], Average Loss: 0.01168441
# Test fold 4, Epoch [170], Average Loss: 0.00870028
# Test fold 4, Epoch [180], Average Loss: 0.00540461
# Test fold 4, Epoch [190], Average Loss: 0.00660639
# Test fold 4, Epoch [200], Average Loss: 0.00674021
# Test fold 4, Epoch [210], Average Loss: 0.00390081
# Test fold 4, Epoch [220], Average Loss: 0.00308927
# Test fold 4, Epoch [230], Average Loss: 0.00341147
# Test fold 4, Epoch [240], Average Loss: 0.00870144
# Test fold 4, Epoch [250], Average Loss: 0.00086422
# Test fold 4, Epoch [260], Average Loss: 0.00388964
# Test fold 4, Epoch [270], Average Loss: 0.00459221
# Test fold 4, Epoch [280], Average Loss: 0.00366307
# Test fold 4, Epoch [290], Average Loss: 0.00268019
# Test fold 4, Epoch [300], Average Loss: 0.00311265
# Test fold 4, Epoch [310], Average Loss: 0.00727285
# Test fold 4, Epoch [320], Average Loss: 0.00347697
# Test fold 4, Epoch [330], Average Loss: 0.00156047
# Test fold 4, Epoch [340], Average Loss: 0.01367242
# Test fold 4, Epoch [350], Average Loss: 0.00031059
# Test fold 4, Epoch [360], Average Loss: 0.00216309
# Test fold 4, Epoch [370], Average Loss: 0.00080671
# Test fold 4, Epoch [380], Average Loss: 0.00088492
# Test fold 4, Epoch [390], Average Loss: 0.00024252
# Test fold 4, Epoch [400], Average Loss: 0.00114659
# Test fold 4, Epoch [410], Average Loss: 0.00160789
# Test fold 4, Epoch [420], Average Loss: 0.00022841
# Test fold 4, Epoch [430], Average Loss: 0.00059910
# Test fold 4, Epoch [440], Average Loss: 0.00280262
# Test fold 4, Epoch [450], Average Loss: 0.00078507
# Test fold 4, Epoch [460], Average Loss: 0.00375391
# Test fold 4, Epoch [470], Average Loss: 0.00583271
# Early stopping triggered after 478 epochs.
# Test fold 5, Epoch [0], Average Loss: 0.27450987
# Test fold 5, Epoch [10], Average Loss: 0.15301355
# Test fold 5, Epoch [20], Average Loss: 0.12082599
# Test fold 5, Epoch [30], Average Loss: 0.10569241
# Test fold 5, Epoch [40], Average Loss: 0.09560576
# Test fold 5, Epoch [50], Average Loss: 0.09579038
# Test fold 5, Epoch [60], Average Loss: 0.06769518
# Test fold 5, Epoch [70], Average Loss: 0.06201606
# Test fold 5, Epoch [80], Average Loss: 0.04663251
# Test fold 5, Epoch [90], Average Loss: 0.03388093
# Test fold 5, Epoch [100], Average Loss: 0.03509333
# Test fold 5, Epoch [110], Average Loss: 0.02608799
# Test fold 5, Epoch [120], Average Loss: 0.01961046
# Test fold 5, Epoch [130], Average Loss: 0.02192978
# Test fold 5, Epoch [140], Average Loss: 0.01476219
# Test fold 5, Epoch [150], Average Loss: 0.01460701
# Test fold 5, Epoch [160], Average Loss: 0.00831928
# Test fold 5, Epoch [170], Average Loss: 0.00919775
# Test fold 5, Epoch [180], Average Loss: 0.00639440
# Test fold 5, Epoch [190], Average Loss: 0.00398357
# Test fold 5, Epoch [200], Average Loss: 0.00292500
# Test fold 5, Epoch [210], Average Loss: 0.00299236
# Test fold 5, Epoch [220], Average Loss: 0.00605718
# Test fold 5, Epoch [230], Average Loss: 0.00102946
# Test fold 5, Epoch [240], Average Loss: 0.00170151
# Test fold 5, Epoch [250], Average Loss: 0.01238071
# Test fold 5, Epoch [260], Average Loss: 0.00776206
# Test fold 5, Epoch [270], Average Loss: 0.00404115
# Test fold 5, Epoch [280], Average Loss: 0.00313481
# Test fold 5, Epoch [290], Average Loss: 0.00145721
# Test fold 5, Epoch [300], Average Loss: 0.00273479
# Test fold 5, Epoch [310], Average Loss: 0.00365410
# Test fold 5, Epoch [320], Average Loss: 0.00335404
# Test fold 5, Epoch [330], Average Loss: 0.02548783
# Test fold 5, Epoch [340], Average Loss: 0.00353463
# Test fold 5, Epoch [350], Average Loss: 0.00121101
# Test fold 5, Epoch [360], Average Loss: 0.00152798
# Test fold 5, Epoch [370], Average Loss: 0.00840992
# Test fold 5, Epoch [380], Average Loss: 0.00155124
# Test fold 5, Epoch [390], Average Loss: 0.00301047
# Early stopping triggered after 394 epochs.
# Test fold 6, Epoch [0], Average Loss: 0.26687331
# Test fold 6, Epoch [10], Average Loss: 0.14930413
# Test fold 6, Epoch [20], Average Loss: 0.11109315
# Test fold 6, Epoch [30], Average Loss: 0.13300183
# Test fold 6, Epoch [40], Average Loss: 0.09102469
# Test fold 6, Epoch [50], Average Loss: 0.07558166
# Test fold 6, Epoch [60], Average Loss: 0.07084648
# Test fold 6, Epoch [70], Average Loss: 0.05286002
# Test fold 6, Epoch [80], Average Loss: 0.04177542
# Test fold 6, Epoch [90], Average Loss: 0.07222326
# Test fold 6, Epoch [100], Average Loss: 0.03732641
# Test fold 6, Epoch [110], Average Loss: 0.02299954
# Test fold 6, Epoch [120], Average Loss: 0.09240410
# NaN loss detected at Epoch [127], Step [759]. Saving model before NaN occurred.
