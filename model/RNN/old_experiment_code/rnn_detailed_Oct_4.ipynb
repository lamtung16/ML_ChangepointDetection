# %%
import pandas as pd
import lzma
import torch
import torch.nn as nn
import numpy as np
import random

# %%
dataset = 'detailed'

# %%
# Hinged Square Loss
class SquaredHingeLoss(nn.Module):
    def __init__(self, margin=1):
        super(SquaredHingeLoss, self).__init__()
        self.margin = margin

    def forward(self, predicted, y):
        low, high = y[:, 0:1], y[:, 1:2]
        loss_low = torch.relu(low - predicted + self.margin)
        loss_high = torch.relu(predicted - high + self.margin)
        loss = loss_low + loss_high
        return torch.mean(torch.square(loss))

# %%
# Define the LSTM model
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, 1)  # Output layer

    def forward(self, x):               # x shape: (batch_size, seq_length, input_size)
        lstm_out, _ = self.lstm(x)      # lstm_out shape: (batch_size, seq_length, hidden_size)
        last_out = lstm_out[:, -1, :]   # last_out shape: (batch_size, hidden_size)
        x = self.fc(last_out)           # x shape: (batch_size, 1)
        x = 7 * torch.tanh(x)           # Apply 7 * tanh() to the output
        return x

# %%
# Function to test the model
def test_model(model, inputs):
    model.eval()
    predictions = []

    with torch.no_grad():
        for seq_input in inputs:
            seq_input = seq_input.unsqueeze(0).unsqueeze(-1)
            output_seq = model(seq_input)
            predictions.append(output_seq.item())

    return predictions

# %%
file_path = f'../../sequence_data/{dataset}/profiles.csv.xz'
with lzma.open(file_path, 'rt') as file:
    signal_df = pd.read_csv(file)

seqs = tuple(signal_df.groupby('sequenceID'))

# %%
# Load data
folds_df = pd.read_csv(f'../../training_data/{dataset}/folds.csv')
target_df = pd.read_csv(f'../../training_data/{dataset}/target.csv')

for test_fold in range(1, np.unique(folds_df['fold']).__len__() + 1):
    # Split data into training and test sets
    train_ids = folds_df[folds_df['fold'] != test_fold]['sequenceID']
    test_ids = folds_df[folds_df['fold'] == test_fold]['sequenceID']

    # train sequences
    train_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(train_ids)]

    # test sequences
    test_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(test_ids)]
    
    # train target
    target_df_train = target_df[target_df['sequenceID'].isin(train_ids)]
    y_train = torch.tensor(target_df_train.iloc[:, 1:].to_numpy())

    # Initialize the model, loss function, and optimizer
    model = LSTMModel(1, 16, 2)
    criterion = SquaredHingeLoss()
    optimizer = torch.optim.Adam(model.parameters())

    # Initialize variables for best loss and best model
    best_loss = float('inf')    # Set best_loss to infinity initially
    patience_counter = 0        # Counter for early stopping
    patience = 50               # Number of epochs to wait for improvement before stopping
    best_model_state = None     # Variable to store the best model parameters

    # Training loop
    for epoch in range(1000):
        combined = list(zip(train_seqs, y_train))   # Combine sequences and targets
        random.shuffle(combined)                    # Shuffle both train_seqs and y_train together
        train_seqs, y_train = zip(*combined)        # Unzip them back into separate lists

        total_loss = 0
        nan_flag = False  # Flag to detect NaN loss

        for i, seq_input in enumerate(train_seqs):
            # Prepare input and target for the current sequence
            target = y_train[i].unsqueeze(0)  # Get the corresponding target for the sequence

            # Zero the gradients
            optimizer.zero_grad()

            # Forward pass
            seq_input = seq_input.unsqueeze(0).unsqueeze(-1)  # Shape: (1, seq_length, input_size)
            output_seq = model(seq_input)                     # Get model output for the sequence
            loss = criterion(output_seq, target.unsqueeze(-1))  # Calculate loss

            # Check for NaN loss
            if torch.isnan(loss).any():
                print(f"NaN loss detected at Epoch [{epoch}], Step [{i}]. Saving model before NaN occurred.")
                torch.save(best_model_state, 'model_before_nan.pth')  # Save model state before NaN loss
                nan_flag = True
                break  # Exit the training loop if NaN is encountered

            # Backward pass and optimize
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        if nan_flag:
            break  # Stop training if NaN was encountered

        # Calculate average loss for this epoch
        average_loss = total_loss / len(train_seqs)
        if epoch % 10 == 0:
            print(f'Test fold {test_fold}, Epoch [{epoch}], Average Loss: {average_loss:.8f}')

        # Early stopping logic
        if average_loss < best_loss:
            best_loss = average_loss  # Update best loss
            patience_counter = 0  # Reset patience counter

            # Save the best model parameters in memory
            best_model_state = model.state_dict()  # Store the model parameters
        else:
            patience_counter += 1  # Increment patience counter

        # Stop training if patience is exceeded
        if patience_counter >= patience:
            print(f'Early stopping triggered after {epoch + 1} epochs.')
            break
    
    # After training, you can restore the best model parameters if needed
    if best_model_state is not None:
        model.load_state_dict(best_model_state)
        model.eval()  # Set the model to evaluation mode
    
    # Test the model and collect outputs
    pred_lldas = test_model(model, test_seqs)

    # Save to CSV
    lldas_df = pd.DataFrame(list(zip(test_ids, pred_lldas)), columns=['sequenceID', 'llda'])
    lldas_df.to_csv(f'predictions/proposed.{dataset}.{test_fold}.csv', index=False)
# Out:
# Test fold 1, Epoch [0], Average Loss: 0.46481630
# Test fold 1, Epoch [10], Average Loss: 0.34865262
# Test fold 1, Epoch [20], Average Loss: 0.29276890
# Test fold 1, Epoch [30], Average Loss: 0.26231537
# Test fold 1, Epoch [40], Average Loss: 0.25448914
# Test fold 1, Epoch [50], Average Loss: 0.22291979
# Test fold 1, Epoch [60], Average Loss: 0.19289781
# Test fold 1, Epoch [70], Average Loss: 0.22121528
# Test fold 1, Epoch [80], Average Loss: 0.15772047
# Test fold 1, Epoch [90], Average Loss: 0.12858469
# Test fold 1, Epoch [100], Average Loss: 0.11251230
# Test fold 1, Epoch [110], Average Loss: 0.10531340
# Test fold 1, Epoch [120], Average Loss: 0.16416614
# Test fold 1, Epoch [130], Average Loss: 0.36207212
# Test fold 1, Epoch [140], Average Loss: 0.14088211
# Test fold 1, Epoch [150], Average Loss: 0.10753226
# Test fold 1, Epoch [160], Average Loss: 0.07836540
# Test fold 1, Epoch [170], Average Loss: 0.07547396
# Test fold 1, Epoch [180], Average Loss: 0.05787634
# Test fold 1, Epoch [190], Average Loss: 0.05871758
# Test fold 1, Epoch [200], Average Loss: 0.05326248
# Test fold 1, Epoch [210], Average Loss: 0.04680552
# Test fold 1, Epoch [220], Average Loss: 0.05365233
# Test fold 1, Epoch [230], Average Loss: 0.03943566
# Test fold 1, Epoch [240], Average Loss: 0.04692843
# Test fold 1, Epoch [250], Average Loss: 0.03538464
# Test fold 1, Epoch [260], Average Loss: 0.03711323
# Test fold 1, Epoch [270], Average Loss: 0.03403677
# Test fold 1, Epoch [280], Average Loss: 0.03309582
# Test fold 1, Epoch [290], Average Loss: 0.03293314
# Test fold 1, Epoch [300], Average Loss: 0.03457126
# Test fold 1, Epoch [310], Average Loss: 0.03292214
# Test fold 1, Epoch [320], Average Loss: 0.03361674
# Test fold 1, Epoch [330], Average Loss: 0.03280995
# Test fold 1, Epoch [340], Average Loss: 0.03127454
# Test fold 1, Epoch [350], Average Loss: 0.03106110
# Test fold 1, Epoch [360], Average Loss: 0.03062496
# Test fold 1, Epoch [370], Average Loss: 0.02732124
# Test fold 1, Epoch [380], Average Loss: 0.02906821
# Test fold 1, Epoch [390], Average Loss: 0.03002558
# Test fold 1, Epoch [400], Average Loss: 0.03070605
# Test fold 1, Epoch [410], Average Loss: 0.03008440
# Test fold 1, Epoch [420], Average Loss: 0.02647441
# Test fold 1, Epoch [430], Average Loss: 0.02584009
# Test fold 1, Epoch [440], Average Loss: 0.02550978
# Test fold 1, Epoch [450], Average Loss: 0.02677037
# Test fold 1, Epoch [460], Average Loss: 0.02933162
# Test fold 1, Epoch [470], Average Loss: 0.02438759
# Test fold 1, Epoch [480], Average Loss: 0.02902519
# Test fold 1, Epoch [490], Average Loss: 0.02928652
# Early stopping triggered after 498 epochs.
# Test fold 2, Epoch [0], Average Loss: 0.45303815
# Test fold 2, Epoch [10], Average Loss: 0.38820647
# Test fold 2, Epoch [20], Average Loss: 0.30255807
# Test fold 2, Epoch [30], Average Loss: 0.27891048
# Test fold 2, Epoch [40], Average Loss: 0.28041480
# Test fold 2, Epoch [50], Average Loss: 0.26312853
# Test fold 2, Epoch [60], Average Loss: 0.23893007
# Test fold 2, Epoch [70], Average Loss: 0.20220750
# Test fold 2, Epoch [80], Average Loss: 0.18193253
# Test fold 2, Epoch [90], Average Loss: 0.15312428
# Test fold 2, Epoch [100], Average Loss: 0.13846646
# Test fold 2, Epoch [110], Average Loss: 0.12697245
# Test fold 2, Epoch [120], Average Loss: 0.11534271
# Test fold 2, Epoch [130], Average Loss: 0.12745948
# Test fold 2, Epoch [140], Average Loss: 0.10322990
# Test fold 2, Epoch [150], Average Loss: 0.09594768
# Test fold 2, Epoch [160], Average Loss: 0.07338392
# Test fold 2, Epoch [170], Average Loss: 0.06982030
# Test fold 2, Epoch [180], Average Loss: 0.05910200
# Test fold 2, Epoch [190], Average Loss: 0.05784622
# Test fold 2, Epoch [200], Average Loss: 0.05147662
# Test fold 2, Epoch [210], Average Loss: 0.04721758
# Test fold 2, Epoch [220], Average Loss: 0.03940995
# Test fold 2, Epoch [230], Average Loss: 0.03761177
# Test fold 2, Epoch [240], Average Loss: 0.03638913
# Test fold 2, Epoch [250], Average Loss: 0.04693919
# Test fold 2, Epoch [260], Average Loss: 0.03040947
# Test fold 2, Epoch [270], Average Loss: 0.03247121
# Test fold 2, Epoch [280], Average Loss: 0.03219470
# Test fold 2, Epoch [290], Average Loss: 0.02956380
# Test fold 2, Epoch [300], Average Loss: 0.03092425
# Test fold 2, Epoch [310], Average Loss: 0.03334789
# Test fold 2, Epoch [320], Average Loss: 0.02810924
# Test fold 2, Epoch [330], Average Loss: 0.03074779
# Test fold 2, Epoch [340], Average Loss: 0.03299800
# Test fold 2, Epoch [350], Average Loss: 0.03355553
# Test fold 2, Epoch [360], Average Loss: 0.03163182
# Test fold 2, Epoch [370], Average Loss: 0.02978436
# Early stopping triggered after 379 epochs.
# Test fold 3, Epoch [0], Average Loss: 0.48084313
# Test fold 3, Epoch [10], Average Loss: 0.35900656
# Test fold 3, Epoch [20], Average Loss: 0.31795804
# Test fold 3, Epoch [30], Average Loss: 0.24630864
# Test fold 3, Epoch [40], Average Loss: 0.21163512
# Test fold 3, Epoch [50], Average Loss: 0.18549968
# Test fold 3, Epoch [60], Average Loss: 0.16287054
# Test fold 3, Epoch [70], Average Loss: 0.14437454
# Test fold 3, Epoch [80], Average Loss: 0.11678588
# Test fold 3, Epoch [90], Average Loss: 0.11048386
# Test fold 3, Epoch [100], Average Loss: 0.08821002
# Test fold 3, Epoch [110], Average Loss: 0.08216736
# Test fold 3, Epoch [120], Average Loss: 0.07342083
# Test fold 3, Epoch [130], Average Loss: 0.06660474
# Test fold 3, Epoch [140], Average Loss: 0.05621167
# Test fold 3, Epoch [150], Average Loss: 0.07246827
# Test fold 3, Epoch [160], Average Loss: 0.04718811
# Test fold 3, Epoch [170], Average Loss: 0.05003939
# Test fold 3, Epoch [180], Average Loss: 0.04612538
# Test fold 3, Epoch [190], Average Loss: 0.04831136
# Test fold 3, Epoch [200], Average Loss: 0.05155084
# Test fold 3, Epoch [210], Average Loss: 0.03558598
# Test fold 3, Epoch [220], Average Loss: 0.04168203
# Test fold 3, Epoch [230], Average Loss: 0.03624628
# Test fold 3, Epoch [240], Average Loss: 0.04002713
# Test fold 3, Epoch [250], Average Loss: 0.03674624
# Test fold 3, Epoch [260], Average Loss: 0.03362014
# Test fold 3, Epoch [270], Average Loss: 0.03891490
# Test fold 3, Epoch [280], Average Loss: 0.03764762
# Test fold 3, Epoch [290], Average Loss: 0.03316849
# Test fold 3, Epoch [300], Average Loss: 0.03784303
# Test fold 3, Epoch [310], Average Loss: 0.03079002
# Test fold 3, Epoch [320], Average Loss: 0.04061870
# Test fold 3, Epoch [330], Average Loss: 0.03107312
# Test fold 3, Epoch [340], Average Loss: 0.03309848
# Test fold 3, Epoch [350], Average Loss: 0.02918656
# Test fold 3, Epoch [360], Average Loss: 0.03421692
# Test fold 3, Epoch [370], Average Loss: 0.02974097
# Test fold 3, Epoch [380], Average Loss: 0.02829250
# Test fold 3, Epoch [390], Average Loss: 0.03023569
# Test fold 3, Epoch [400], Average Loss: 0.03113860
# Test fold 3, Epoch [410], Average Loss: 0.02817574
# Test fold 3, Epoch [420], Average Loss: 0.03153631
# Test fold 3, Epoch [430], Average Loss: 0.02661356
# Test fold 3, Epoch [440], Average Loss: 0.03051933
# Test fold 3, Epoch [450], Average Loss: 0.02452439
# Test fold 3, Epoch [460], Average Loss: 0.02654275
# Test fold 3, Epoch [470], Average Loss: 0.02935312
# Test fold 3, Epoch [480], Average Loss: 0.02805381
# Test fold 3, Epoch [490], Average Loss: 0.03026735
# Test fold 3, Epoch [500], Average Loss: 0.02821378
# Early stopping triggered after 501 epochs.
# Test fold 4, Epoch [0], Average Loss: 0.46999193
# Test fold 4, Epoch [10], Average Loss: 0.37867101
# Test fold 4, Epoch [20], Average Loss: 0.37142501
# Test fold 4, Epoch [30], Average Loss: 0.32571250
# Test fold 4, Epoch [40], Average Loss: 0.26267972
# Test fold 4, Epoch [50], Average Loss: 0.23519591
# Test fold 4, Epoch [60], Average Loss: 0.21115578
# Test fold 4, Epoch [70], Average Loss: 0.17378018
# Test fold 4, Epoch [80], Average Loss: 0.14548803
# Test fold 4, Epoch [90], Average Loss: 0.12096340
# Test fold 4, Epoch [100], Average Loss: 0.09359447
# Test fold 4, Epoch [110], Average Loss: 0.08599461
# Test fold 4, Epoch [120], Average Loss: 0.21893286
# Test fold 4, Epoch [130], Average Loss: 0.22300622
# Test fold 4, Epoch [140], Average Loss: 0.16770542
# Test fold 4, Epoch [150], Average Loss: 0.13059878
# Test fold 4, Epoch [160], Average Loss: 0.08454977
# Early stopping triggered after 167 epochs.
# Test fold 5, Epoch [0], Average Loss: 0.45696180
# Test fold 5, Epoch [10], Average Loss: 0.45155088
# Test fold 5, Epoch [20], Average Loss: 0.45174614
# Test fold 5, Epoch [30], Average Loss: 0.45063803
# Test fold 5, Epoch [40], Average Loss: 0.42868554
# Test fold 5, Epoch [50], Average Loss: 0.41120217
# Test fold 5, Epoch [60], Average Loss: 0.43680281
# Early stopping triggered after 69 epochs.
# Test fold 6, Epoch [0], Average Loss: 0.47416714
# Test fold 6, Epoch [10], Average Loss: 0.32484101
# Test fold 6, Epoch [20], Average Loss: 0.29444666
# Test fold 6, Epoch [30], Average Loss: 0.27669166
# Test fold 6, Epoch [40], Average Loss: 0.23490866
# Test fold 6, Epoch [50], Average Loss: 0.23161511
# Test fold 6, Epoch [60], Average Loss: 0.19635068
# Test fold 6, Epoch [70], Average Loss: 0.18853586
# Test fold 6, Epoch [80], Average Loss: 0.16377735
# Test fold 6, Epoch [90], Average Loss: 0.17664792
# Test fold 6, Epoch [100], Average Loss: 0.13659372
# Test fold 6, Epoch [110], Average Loss: 0.23871029
# Test fold 6, Epoch [120], Average Loss: 0.21790932
# Test fold 6, Epoch [130], Average Loss: 0.17080605
# Test fold 6, Epoch [140], Average Loss: 0.14317141
# Test fold 6, Epoch [150], Average Loss: 0.20538124
# Early stopping triggered after 153 epochs.
