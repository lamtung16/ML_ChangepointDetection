# %%
import pandas as pd
import lzma
import torch
import torch.nn as nn
import numpy as np
import random
from sklearn.model_selection import train_test_split
from torch.utils.data import Dataset, DataLoader

# %%
dataset = 'detailed'
test_fold = 1

nonlinearity='tanh'
hidden_size = 8
num_layers = 2

max_epoch = 1000
patience = 50

# %%
# Hinged Square Loss
class SquaredHingeLoss(nn.Module):
    def __init__(self, margin=1):
        super(SquaredHingeLoss, self).__init__()
        self.margin = margin

    def forward(self, predicted, y):
        low, high = y[:, 0:1], y[:, 1:2]
        loss_low = torch.relu(low - predicted + self.margin)
        loss_high = torch.relu(predicted - high + self.margin)
        loss = loss_low + loss_high
        return torch.mean(torch.square(loss))

# %%
# Define the RNN model
class RNNModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(RNNModel, self).__init__()
        self.rnn = nn.RNN(input_size, hidden_size, num_layers, batch_first=True, nonlinearity=nonlinearity)
        self.fc = nn.Linear(hidden_size, 1)

    def forward(self, x, lengths):
        # x is PackedSequence
        packed_output, hidden = self.rnn(x)
        # Get the last hidden state from the last layer
        last_hidden = hidden[-1]  # Shape: (batch_size, hidden_size)
        x = self.fc(last_hidden)
        x = torch.relu(x + 10) - torch.relu(x - 10) - 10
        return x

# %%
# Custom Dataset
class SequenceDataset(torch.utils.data.Dataset):
    def __init__(self, sequences, targets):
        self.sequences = sequences
        self.targets = targets

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        return self.sequences[idx], self.targets[idx]

# %%
# Collate function for DataLoader
def collate_fn(batch):
    sequences, targets = zip(*batch)
    # Get lengths of each sequence
    lengths = torch.tensor([len(seq) for seq in sequences], dtype=torch.long)
    # Pad sequences to the same length
    sequences_padded = torch.nn.utils.rnn.pad_sequence(sequences, batch_first=True)
    # Stack targets
    targets = torch.stack(targets)
    return sequences_padded.unsqueeze(-1), targets, lengths

# %%
# Function to compute loss value
def get_loss_value(model, data_loader, criterion):
    model.eval()
    total_loss = 0
    total_samples = 0
    with torch.no_grad():
        for seq_inputs, targets, lengths in data_loader:
            seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
            outputs = model(seq_inputs_packed, lengths)
            loss = criterion(outputs, targets.unsqueeze(-1))
            batch_size = seq_inputs.size(0)
            total_loss += loss.item() * batch_size
            total_samples += batch_size
    average_loss = total_loss / total_samples
    return average_loss

# %%
# Function to test the model
def test_model(model, data_loader):
    model.eval()
    predictions = []
    with torch.no_grad():
        for seq_inputs, _, lengths in data_loader:
            seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
            outputs = model(seq_inputs_packed, lengths)
            predictions.extend(outputs.squeeze(-1).tolist())
    return predictions

# %%
# Load data
file_path = f'../../sequence_data/{dataset}/profiles.csv.xz'
with lzma.open(file_path, 'rt') as file:
    signal_df = pd.read_csv(file)

seqs = tuple(signal_df.groupby('sequenceID'))

# Load data
folds_df = pd.read_csv(f'../../training_data/{dataset}/folds.csv')
target_df = pd.read_csv(f'../../training_data/{dataset}/target.csv')

# Split data into training and test sets
train_ids = folds_df[folds_df['fold'] != test_fold]['sequenceID']
test_ids = folds_df[folds_df['fold'] == test_fold]['sequenceID']

# Train sequences
train_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(train_ids)]

# Test sequences
test_seqs = [torch.tensor(seq[1]['signal'].to_numpy(), dtype=torch.float32) for seq in seqs if seq[0] in list(test_ids)]

# Targets
target_df_train = target_df[target_df['sequenceID'].isin(train_ids)]
target_df_test = target_df[target_df['sequenceID'].isin(test_ids)]
y_train = torch.tensor(target_df_train.iloc[:, 1:].to_numpy(), dtype=torch.float32)
y_test = torch.tensor(target_df_test.iloc[:, 1:].to_numpy(), dtype=torch.float32)

# Split train into subtrain and validation (80% subtrain, 20% validation)
train_seqs, val_seqs, y_train, y_val = train_test_split(train_seqs, y_train, test_size=0.2, random_state=42)

# Create datasets and dataloaders
batch_size = 64

train_dataset = SequenceDataset(train_seqs, y_train)
val_dataset = SequenceDataset(val_seqs, y_val)
test_dataset = SequenceDataset(test_seqs, y_test)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)

# %%
# Initialize the model, loss function, and optimizer
model = RNNModel(1, hidden_size, num_layers)
criterion = SquaredHingeLoss()
optimizer = torch.optim.Adam(model.parameters())

# Initialize variables for best validation loss and best model
best_val_loss = float('inf')    # Set best validation loss to infinity initially
patience_counter = 0            # Counter for early stopping
best_model_state = None         # Variable to store the best model parameters

# Training loop
for epoch in range(max_epoch):
    model.train()
    total_loss = 0
    total_samples = 0

    for seq_inputs, targets, lengths in train_loader:
        optimizer.zero_grad()
        seq_inputs_packed = torch.nn.utils.rnn.pack_padded_sequence(seq_inputs, lengths, batch_first=True, enforce_sorted=False)
        outputs = model(seq_inputs_packed, lengths)
        loss = criterion(outputs, targets.unsqueeze(-1))

        # Stop training if loss is NaN
        if torch.isnan(loss):
            print(f'Stopping training at epoch {epoch} due to NaN loss.')
            break

        # Backward pass and optimize
        loss.backward()
        optimizer.step()

        batch_size = seq_inputs.size(0)
        total_loss += loss.item() * batch_size
        total_samples += batch_size

    # Calculate average loss for this epoch (training)
    average_loss = total_loss / total_samples

    # Validation step
    average_val_loss  = get_loss_value(model, val_loader, criterion)
    average_test_loss = get_loss_value(model, test_loader, criterion)

    if epoch % 1 == 0:
        print(f'Test fold {test_fold} \t Epoch [{epoch:3d}] \t Train Loss: {average_loss:.8f} \t Val Loss: {average_val_loss:.8f} \t Test Loss: {average_test_loss:.8f}')

    # Early stopping logic based on validation loss
    if average_val_loss < best_val_loss:
        best_val_loss = average_val_loss  # Update best validation loss
        patience_counter = 0  # Reset patience counter

        # Save the best model parameters in memory
        best_model_state = model.state_dict()  # Store the model parameters
    else:
        patience_counter += 1  # Increment patience counter

    # Stop training if patience is exceeded or NaN is detected
    if patience_counter >= patience or torch.isnan(loss):
        if torch.isnan(loss):
            print(f'Training stopped due to NaN loss at epoch {epoch}.')
        else:
            print(f'Early stopping triggered after {epoch + 1} epochs.')
        break

# After training, you can restore the best model parameters if needed
if best_model_state is not None:
    model.load_state_dict(best_model_state)
    model.eval()  # Set the model to evaluation mode

# Test the model and collect outputs
pred_lldas = test_model(model, test_loader)

# Save to CSV
lldas_df = pd.DataFrame(list(zip(test_ids, pred_lldas)), columns=['sequenceID', 'llda'])
lldas_df.to_csv(f'predictions/proposed.{dataset}.{hidden_size}.{num_layers}.{nonlinearity}.{patience}.{test_fold}.csv', index=False)
# Out:
# Test fold 1 	 Epoch [  0] 	 Train Loss: 0.46315788 	 Val Loss: 0.46554081 	 Test Loss: 0.45924710
# Test fold 1 	 Epoch [  1] 	 Train Loss: 0.44812264 	 Val Loss: 0.46266621 	 Test Loss: 0.46195017
# Test fold 1 	 Epoch [  2] 	 Train Loss: 0.44759467 	 Val Loss: 0.46367130 	 Test Loss: 0.46035692
# Test fold 1 	 Epoch [  3] 	 Train Loss: 0.44820235 	 Val Loss: 0.46291875 	 Test Loss: 0.46123862
# Test fold 1 	 Epoch [  4] 	 Train Loss: 0.44805673 	 Val Loss: 0.46336527 	 Test Loss: 0.46048710
# Test fold 1 	 Epoch [  5] 	 Train Loss: 0.44815514 	 Val Loss: 0.46250766 	 Test Loss: 0.46175170
# Test fold 1 	 Epoch [  6] 	 Train Loss: 0.44760258 	 Val Loss: 0.46327927 	 Test Loss: 0.46048493
# Test fold 1 	 Epoch [  7] 	 Train Loss: 0.44812671 	 Val Loss: 0.46294058 	 Test Loss: 0.46090453
# Test fold 1 	 Epoch [  8] 	 Train Loss: 0.44757674 	 Val Loss: 0.46275922 	 Test Loss: 0.46113524
# Test fold 1 	 Epoch [  9] 	 Train Loss: 0.44778307 	 Val Loss: 0.46286214 	 Test Loss: 0.46092985
# Test fold 1 	 Epoch [ 10] 	 Train Loss: 0.44789686 	 Val Loss: 0.46310368 	 Test Loss: 0.46055739
# Test fold 1 	 Epoch [ 11] 	 Train Loss: 0.44781973 	 Val Loss: 0.46267984 	 Test Loss: 0.46116328
# Test fold 1 	 Epoch [ 12] 	 Train Loss: 0.44780691 	 Val Loss: 0.46244669 	 Test Loss: 0.46154654
# Test fold 1 	 Epoch [ 13] 	 Train Loss: 0.44775499 	 Val Loss: 0.46334406 	 Test Loss: 0.46026695
# Test fold 1 	 Epoch [ 14] 	 Train Loss: 0.44768542 	 Val Loss: 0.46325965 	 Test Loss: 0.46032597
# Test fold 1 	 Epoch [ 15] 	 Train Loss: 0.44773000 	 Val Loss: 0.46290724 	 Test Loss: 0.46075612
# Test fold 1 	 Epoch [ 16] 	 Train Loss: 0.44832696 	 Val Loss: 0.46327257 	 Test Loss: 0.46027428
# Test fold 1 	 Epoch [ 17] 	 Train Loss: 0.44812449 	 Val Loss: 0.46258751 	 Test Loss: 0.46121599
# Test fold 1 	 Epoch [ 18] 	 Train Loss: 0.44820916 	 Val Loss: 0.46339014 	 Test Loss: 0.46015872
# Test fold 1 	 Epoch [ 19] 	 Train Loss: 0.44825915 	 Val Loss: 0.46296261 	 Test Loss: 0.46068778
# Test fold 1 	 Epoch [ 20] 	 Train Loss: 0.44844101 	 Val Loss: 0.46398934 	 Test Loss: 0.45961869
# Test fold 1 	 Epoch [ 21] 	 Train Loss: 0.44810747 	 Val Loss: 0.46272739 	 Test Loss: 0.46095088
# Test fold 1 	 Epoch [ 22] 	 Train Loss: 0.44829740 	 Val Loss: 0.46279338 	 Test Loss: 0.46087583
# Test fold 1 	 Epoch [ 23] 	 Train Loss: 0.44755681 	 Val Loss: 0.46267998 	 Test Loss: 0.46109031
# Test fold 1 	 Epoch [ 24] 	 Train Loss: 0.44815091 	 Val Loss: 0.46239790 	 Test Loss: 0.46164585
# Test fold 1 	 Epoch [ 25] 	 Train Loss: 0.44815804 	 Val Loss: 0.46431356 	 Test Loss: 0.45939465
# Test fold 1 	 Epoch [ 26] 	 Train Loss: 0.44768346 	 Val Loss: 0.46285863 	 Test Loss: 0.46082123
# Test fold 1 	 Epoch [ 27] 	 Train Loss: 0.44766249 	 Val Loss: 0.46272580 	 Test Loss: 0.46099654
# Test fold 1 	 Epoch [ 28] 	 Train Loss: 0.44778428 	 Val Loss: 0.46305017 	 Test Loss: 0.46058611
# Test fold 1 	 Epoch [ 29] 	 Train Loss: 0.44772308 	 Val Loss: 0.46324253 	 Test Loss: 0.46035661
# Test fold 1 	 Epoch [ 30] 	 Train Loss: 0.44824016 	 Val Loss: 0.46257744 	 Test Loss: 0.46124178
# Test fold 1 	 Epoch [ 31] 	 Train Loss: 0.44846357 	 Val Loss: 0.46323045 	 Test Loss: 0.46025918
# Test fold 1 	 Epoch [ 32] 	 Train Loss: 0.44774077 	 Val Loss: 0.46252986 	 Test Loss: 0.46121286
# Test fold 1 	 Epoch [ 33] 	 Train Loss: 0.44795914 	 Val Loss: 0.46327935 	 Test Loss: 0.46018633
# Test fold 1 	 Epoch [ 34] 	 Train Loss: 0.44770950 	 Val Loss: 0.46257072 	 Test Loss: 0.46119081
# Test fold 1 	 Epoch [ 35] 	 Train Loss: 0.44802112 	 Val Loss: 0.46268734 	 Test Loss: 0.46103217
# Test fold 1 	 Epoch [ 36] 	 Train Loss: 0.44779873 	 Val Loss: 0.46287223 	 Test Loss: 0.46077025
# Test fold 1 	 Epoch [ 37] 	 Train Loss: 0.44801034 	 Val Loss: 0.46286395 	 Test Loss: 0.46082399
# Test fold 1 	 Epoch [ 38] 	 Train Loss: 0.44782242 	 Val Loss: 0.46303188 	 Test Loss: 0.46059271
# Test fold 1 	 Epoch [ 39] 	 Train Loss: 0.44775122 	 Val Loss: 0.46259317 	 Test Loss: 0.46121896
# Test fold 1 	 Epoch [ 40] 	 Train Loss: 0.44774461 	 Val Loss: 0.46291337 	 Test Loss: 0.46070874
# Test fold 1 	 Epoch [ 41] 	 Train Loss: 0.44834810 	 Val Loss: 0.46283818 	 Test Loss: 0.46082229
# Test fold 1 	 Epoch [ 42] 	 Train Loss: 0.44778522 	 Val Loss: 0.46273949 	 Test Loss: 0.46102558
# Test fold 1 	 Epoch [ 43] 	 Train Loss: 0.44798109 	 Val Loss: 0.46279959 	 Test Loss: 0.46088919
# Test fold 1 	 Epoch [ 44] 	 Train Loss: 0.44787475 	 Val Loss: 0.46237881 	 Test Loss: 0.46155761
# Test fold 1 	 Epoch [ 45] 	 Train Loss: 0.44766997 	 Val Loss: 0.46311321 	 Test Loss: 0.46042346
# Test fold 1 	 Epoch [ 46] 	 Train Loss: 0.44813933 	 Val Loss: 0.46268054 	 Test Loss: 0.46109500
# Test fold 1 	 Epoch [ 47] 	 Train Loss: 0.44794579 	 Val Loss: 0.46291643 	 Test Loss: 0.46071032
# Test fold 1 	 Epoch [ 48] 	 Train Loss: 0.44776027 	 Val Loss: 0.46376639 	 Test Loss: 0.45977171
# Test fold 1 	 Epoch [ 49] 	 Train Loss: 0.44848114 	 Val Loss: 0.46329659 	 Test Loss: 0.46026346
# Test fold 1 	 Epoch [ 50] 	 Train Loss: 0.44778563 	 Val Loss: 0.46247040 	 Test Loss: 0.46144089
# Test fold 1 	 Epoch [ 51] 	 Train Loss: 0.44764561 	 Val Loss: 0.46283255 	 Test Loss: 0.46082652
# Test fold 1 	 Epoch [ 52] 	 Train Loss: 0.44780710 	 Val Loss: 0.46248885 	 Test Loss: 0.46145977
# Test fold 1 	 Epoch [ 53] 	 Train Loss: 0.44797694 	 Val Loss: 0.46306448 	 Test Loss: 0.46055088
# Test fold 1 	 Epoch [ 54] 	 Train Loss: 0.44763601 	 Val Loss: 0.46289411 	 Test Loss: 0.46080975
# Test fold 1 	 Epoch [ 55] 	 Train Loss: 0.44794098 	 Val Loss: 0.46328179 	 Test Loss: 0.46030915
# Test fold 1 	 Epoch [ 56] 	 Train Loss: 0.44825622 	 Val Loss: 0.46268889 	 Test Loss: 0.46110214
# Test fold 1 	 Epoch [ 57] 	 Train Loss: 0.44817302 	 Val Loss: 0.46330523 	 Test Loss: 0.46025132
# Test fold 1 	 Epoch [ 58] 	 Train Loss: 0.44802084 	 Val Loss: 0.46380179 	 Test Loss: 0.45974583
# Test fold 1 	 Epoch [ 59] 	 Train Loss: 0.44807533 	 Val Loss: 0.46285707 	 Test Loss: 0.46077856
# Test fold 1 	 Epoch [ 60] 	 Train Loss: 0.44785047 	 Val Loss: 0.46307141 	 Test Loss: 0.46050293
# Test fold 1 	 Epoch [ 61] 	 Train Loss: 0.44760259 	 Val Loss: 0.46292271 	 Test Loss: 0.46066217
# Test fold 1 	 Epoch [ 62] 	 Train Loss: 0.44810538 	 Val Loss: 0.46308015 	 Test Loss: 0.46043844
# Test fold 1 	 Epoch [ 63] 	 Train Loss: 0.44783062 	 Val Loss: 0.46248771 	 Test Loss: 0.46134762
# Test fold 1 	 Epoch [ 64] 	 Train Loss: 0.44763861 	 Val Loss: 0.46287599 	 Test Loss: 0.46072409
# Test fold 1 	 Epoch [ 65] 	 Train Loss: 0.44786954 	 Val Loss: 0.46334117 	 Test Loss: 0.46016715
# Test fold 1 	 Epoch [ 66] 	 Train Loss: 0.44797622 	 Val Loss: 0.46277291 	 Test Loss: 0.46088207
# Test fold 1 	 Epoch [ 67] 	 Train Loss: 0.44771833 	 Val Loss: 0.46302970 	 Test Loss: 0.46053338
# Test fold 1 	 Epoch [ 68] 	 Train Loss: 0.44761232 	 Val Loss: 0.46363470 	 Test Loss: 0.45984931
# Test fold 1 	 Epoch [ 69] 	 Train Loss: 0.44772511 	 Val Loss: 0.46338709 	 Test Loss: 0.46006141
# Test fold 1 	 Epoch [ 70] 	 Train Loss: 0.44776523 	 Val Loss: 0.46225282 	 Test Loss: 0.46183977
# Test fold 1 	 Epoch [ 71] 	 Train Loss: 0.44759503 	 Val Loss: 0.46303738 	 Test Loss: 0.46050711
# Test fold 1 	 Epoch [ 72] 	 Train Loss: 0.44794827 	 Val Loss: 0.46373369 	 Test Loss: 0.45976564
# Test fold 1 	 Epoch [ 73] 	 Train Loss: 0.44845671 	 Val Loss: 0.46241552 	 Test Loss: 0.46148568
# Test fold 1 	 Epoch [ 74] 	 Train Loss: 0.44810325 	 Val Loss: 0.46305411 	 Test Loss: 0.46050367
# Test fold 1 	 Epoch [ 75] 	 Train Loss: 0.44793873 	 Val Loss: 0.46373461 	 Test Loss: 0.45978493
# Test fold 1 	 Epoch [ 76] 	 Train Loss: 0.44781557 	 Val Loss: 0.46327310 	 Test Loss: 0.46020273
# Test fold 1 	 Epoch [ 77] 	 Train Loss: 0.44806635 	 Val Loss: 0.46240202 	 Test Loss: 0.46147374
# Test fold 1 	 Epoch [ 78] 	 Train Loss: 0.44819397 	 Val Loss: 0.46320797 	 Test Loss: 0.46026149
# Test fold 1 	 Epoch [ 79] 	 Train Loss: 0.44790442 	 Val Loss: 0.46265618 	 Test Loss: 0.46103865
# Test fold 1 	 Epoch [ 80] 	 Train Loss: 0.44830352 	 Val Loss: 0.46267259 	 Test Loss: 0.46099702
# Test fold 1 	 Epoch [ 81] 	 Train Loss: 0.44743492 	 Val Loss: 0.46349404 	 Test Loss: 0.45996262
# Test fold 1 	 Epoch [ 82] 	 Train Loss: 0.44762585 	 Val Loss: 0.46316844 	 Test Loss: 0.46030214
# Test fold 1 	 Epoch [ 83] 	 Train Loss: 0.44743689 	 Val Loss: 0.46255948 	 Test Loss: 0.46116544
# Test fold 1 	 Epoch [ 84] 	 Train Loss: 0.44765382 	 Val Loss: 0.46276497 	 Test Loss: 0.46077553
# Test fold 1 	 Epoch [ 85] 	 Train Loss: 0.44751773 	 Val Loss: 0.46285140 	 Test Loss: 0.46068328
# Test fold 1 	 Epoch [ 86] 	 Train Loss: 0.44758338 	 Val Loss: 0.46286154 	 Test Loss: 0.46068174
# Test fold 1 	 Epoch [ 87] 	 Train Loss: 0.44765146 	 Val Loss: 0.46276317 	 Test Loss: 0.46078374
# Test fold 1 	 Epoch [ 88] 	 Train Loss: 0.44809664 	 Val Loss: 0.46225483 	 Test Loss: 0.46173005
# Test fold 1 	 Epoch [ 89] 	 Train Loss: 0.44917818 	 Val Loss: 0.46323498 	 Test Loss: 0.46019326
# Test fold 1 	 Epoch [ 90] 	 Train Loss: 0.44772339 	 Val Loss: 0.46225474 	 Test Loss: 0.46173794
# Test fold 1 	 Epoch [ 91] 	 Train Loss: 0.44812014 	 Val Loss: 0.46302864 	 Test Loss: 0.46042281
# Test fold 1 	 Epoch [ 92] 	 Train Loss: 0.44773952 	 Val Loss: 0.46255313 	 Test Loss: 0.46111388
# Test fold 1 	 Epoch [ 93] 	 Train Loss: 0.44755631 	 Val Loss: 0.46290023 	 Test Loss: 0.46058617
# Test fold 1 	 Epoch [ 94] 	 Train Loss: 0.44757790 	 Val Loss: 0.46279270 	 Test Loss: 0.46074127
# Test fold 1 	 Epoch [ 95] 	 Train Loss: 0.44803950 	 Val Loss: 0.46319931 	 Test Loss: 0.46021825
# Test fold 1 	 Epoch [ 96] 	 Train Loss: 0.44759975 	 Val Loss: 0.46265661 	 Test Loss: 0.46096466
# Test fold 1 	 Epoch [ 97] 	 Train Loss: 0.44755591 	 Val Loss: 0.46268124 	 Test Loss: 0.46090748
# Test fold 1 	 Epoch [ 98] 	 Train Loss: 0.44766487 	 Val Loss: 0.46256402 	 Test Loss: 0.46110170
# Test fold 1 	 Epoch [ 99] 	 Train Loss: 0.44767538 	 Val Loss: 0.46274501 	 Test Loss: 0.46085516
# Test fold 1 	 Epoch [100] 	 Train Loss: 0.44781095 	 Val Loss: 0.46343925 	 Test Loss: 0.46002600
# Test fold 1 	 Epoch [101] 	 Train Loss: 0.44751211 	 Val Loss: 0.46281482 	 Test Loss: 0.46076136
# Test fold 1 	 Epoch [102] 	 Train Loss: 0.44844624 	 Val Loss: 0.46291364 	 Test Loss: 0.46062141
# Test fold 1 	 Epoch [103] 	 Train Loss: 0.44754024 	 Val Loss: 0.46314923 	 Test Loss: 0.46033243
# Test fold 1 	 Epoch [104] 	 Train Loss: 0.44765743 	 Val Loss: 0.46320651 	 Test Loss: 0.46025856
# Test fold 1 	 Epoch [105] 	 Train Loss: 0.44763760 	 Val Loss: 0.46279825 	 Test Loss: 0.46079041
# Test fold 1 	 Epoch [106] 	 Train Loss: 0.44754136 	 Val Loss: 0.46271290 	 Test Loss: 0.46092665
# Test fold 1 	 Epoch [107] 	 Train Loss: 0.44757426 	 Val Loss: 0.46282268 	 Test Loss: 0.46074314
# Test fold 1 	 Epoch [108] 	 Train Loss: 0.44756554 	 Val Loss: 0.46281914 	 Test Loss: 0.46073590
# Test fold 1 	 Epoch [109] 	 Train Loss: 0.44777923 	 Val Loss: 0.46312490 	 Test Loss: 0.46031297
# Test fold 1 	 Epoch [110] 	 Train Loss: 0.44814915 	 Val Loss: 0.46312051 	 Test Loss: 0.46031371
# Test fold 1 	 Epoch [111] 	 Train Loss: 0.44767410 	 Val Loss: 0.46283113 	 Test Loss: 0.46075310
# Test fold 1 	 Epoch [112] 	 Train Loss: 0.44773100 	 Val Loss: 0.46275198 	 Test Loss: 0.46089477
# Test fold 1 	 Epoch [113] 	 Train Loss: 0.44748638 	 Val Loss: 0.46303990 	 Test Loss: 0.46048110
# Test fold 1 	 Epoch [114] 	 Train Loss: 0.44766888 	 Val Loss: 0.46273594 	 Test Loss: 0.46089283
# Test fold 1 	 Epoch [115] 	 Train Loss: 0.44760642 	 Val Loss: 0.46312920 	 Test Loss: 0.46036818
# Test fold 1 	 Epoch [116] 	 Train Loss: 0.44768667 	 Val Loss: 0.46280186 	 Test Loss: 0.46081372
# Test fold 1 	 Epoch [117] 	 Train Loss: 0.44786215 	 Val Loss: 0.46262763 	 Test Loss: 0.46108745
# Test fold 1 	 Epoch [118] 	 Train Loss: 0.44760099 	 Val Loss: 0.46310256 	 Test Loss: 0.46042751
# Test fold 1 	 Epoch [119] 	 Train Loss: 0.44810492 	 Val Loss: 0.46330836 	 Test Loss: 0.46018182
# Test fold 1 	 Epoch [120] 	 Train Loss: 0.44784164 	 Val Loss: 0.46249239 	 Test Loss: 0.46130538
# Early stopping triggered after 121 epochs.
