# %%
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import KFold
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from joblib import Parallel, delayed
from ipynb.fs.full.utility_functions import gen_data_dict, get_data, error_count, opart, show_error_rate, SquaredHingeLoss

np.random.seed(5)
torch.manual_seed(5)

# %%
def downsize_df(df, downsize):
    return df.groupby(['sequenceID', df.groupby('sequenceID').cumcount() // downsize]).agg({'data.i': 'first', 'logratio': 'mean'}).reset_index(level=1, drop=True).reset_index()

# %%
# sequences
seqs = gen_data_dict('0_sequences_labels/signals.gz')
labels = gen_data_dict('0_sequences_labels/labels.gz')

X = ()
for s in seqs:
    new_seq = (s[0], downsize_df(s[1], len(s[1])//100+1))
    X += (new_seq, )

# target
target_df_1 = pd.read_csv('1_training_data/target_lambda_fold1_base_e.csv')
target_df_2 = pd.read_csv('1_training_data/target_lambda_fold2_base_e.csv')

targets_low_1  = target_df_1.iloc[:, 1:2].to_numpy()
targets_high_1 = target_df_1.iloc[:, 2:3].to_numpy()
targets_low_2  = target_df_2.iloc[:, 1:2].to_numpy()
targets_high_2 = target_df_2.iloc[:, 2:3].to_numpy()

targets_low_1  = torch.FloatTensor(targets_low_1)
targets_high_1 = torch.FloatTensor(targets_high_1)
targets_low_2  = torch.FloatTensor(targets_low_2)
targets_high_2 = torch.FloatTensor(targets_high_2)

y1_raw = torch.cat((targets_low_1, targets_high_1), dim=1)
y2_raw = torch.cat((targets_low_2, targets_high_2), dim=1)

# %%
# filter
idx_fold1 = [idx for idx, item in enumerate(y1_raw) if item[0] > -np.inf and item[1] < np.inf]
X1 = [X[i] for i in idx_fold1]
y1 = y1_raw[idx_fold1]

idx_fold2 = [idx for idx, item in enumerate(y2_raw) if item[0] > -np.inf and item[1] < np.inf]
X2 = [X[i] for i in idx_fold2]
y2 = y2_raw[idx_fold2]

# %%
print(len(X1), len(X2))
print(len(y1), len(y2))
# Out:
# 190 313
# 190 313

# %%
# Define the RNN model
class RNNModel(nn.Module):
    def __init__(self, extracted_features, hidden_layers, hidden_size):
        super(RNNModel, self).__init__()
        # M1
        self.rnn = nn.RNN(input_size=1, hidden_size=extracted_features, num_layers=1, nonlinearity='tanh', bias=True, batch_first=False)
        # M2
        self.hidden_layers = hidden_layers
        self.hidden_size   = hidden_size
        # Define input layer
        self.input_layer = nn.Linear(extracted_features, hidden_size)
        # Define hidden layers
        self.hidden = nn.ModuleList([nn.Linear(hidden_size, hidden_size) for _ in range(hidden_layers)])
        # Define output layer
        self.output_layer = nn.Linear(hidden_size, 1)

    def forward(self, x):
        # M1
        _, x = self.rnn(x)
        # M2
        # Forward pass through input layer
        x = torch.relu(self.input_layer(x))
        # Forward pass through hidden layers
        for layer in self.hidden:
            x = torch.relu(layer(x))
        # Forward pass through output layer
        x = self.output_layer(x)
        return x

# %%
def plot_loss(train_loss, val_loss, train_set_name, test_set_name):
    epochs = range(1, len(train_loss) + 1)
    plt.plot(epochs, train_loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    
    # Find the index of the minimum validation loss
    min_val_loss_index = val_loss.index(min(val_loss))
    min_val_loss = val_loss[min_val_loss_index]
    
    # Mark the minimum validation loss point
    plt.plot(min_val_loss_index + 1, min_val_loss, 'g*', markersize=10, label=f'Min Val epoch: {min_val_loss_index: 3d}')

    plt.title('Train ' + train_set_name + " Validate " + test_set_name)
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %%
def train_model(X, y, X_test, y_test, extracted_features, n_hiddens, layer_size, n_ites):
    model = RNNModel(extracted_features=extracted_features, hidden_layers=n_hiddens, hidden_size=layer_size)
    loss_func = SquaredHingeLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.0001)

    # Training loop
    train_losses = []
    val_losses = []
    for i in range(n_ites+1):
        loss_sum = 0.0
        val_loss_sum = 0.0

        for j in range(len(X)):
            model.train()
            optimizer.zero_grad()

            seq = torch.tensor(X[j][1]['logratio'].to_numpy(), dtype=torch.float32).reshape(-1,1)
            output = model(seq)
            loss = loss_func(output[0], y[j].view(1,-1))
            loss_sum += loss.item()

            loss.backward()
            optimizer.step()

        train_losses.append(loss_sum / len(X))

        with torch.no_grad():
            for k in range(len(X_test)):
                seq = torch.tensor(X_test[k][1]['logratio'].to_numpy(), dtype=torch.float32).reshape(-1, 1)
                val_output = model(seq)
                val_loss = loss_func(val_output[0], y_test[k].view(1,-1))
                val_loss_sum += val_loss.item()
            val_losses.append(val_loss_sum / len(y_test))
        
        print("epoch: %d \t train_loss: %7.5f \t test_loss: %7.5f" % (i, loss_sum/len(X), val_loss_sum/len(y_test)))
    
    return model, train_losses, val_losses

# %%
model, train_losses, val_losses = train_model(X=X1, y=y1, X_test=X2, y_test=y2, extracted_features=12, n_hiddens=0, layer_size=8, n_ites=100)
plot_loss(train_losses, val_losses, train_set_name='X1', test_set_name='X2')
# Out:
# epoch: 0 	 train_loss: 2.55405 	 test_loss: 1.20836
# epoch: 1 	 train_loss: 2.42807 	 test_loss: 1.26454
# epoch: 2 	 train_loss: 2.37631 	 test_loss: 1.28932
# epoch: 3 	 train_loss: 2.36071 	 test_loss: 1.30410
# epoch: 4 	 train_loss: 2.35142 	 test_loss: 1.31211
# epoch: 5 	 train_loss: 2.34540 	 test_loss: 1.31680
# epoch: 6 	 train_loss: 2.34115 	 test_loss: 1.32130
# epoch: 7 	 train_loss: 2.33724 	 test_loss: 1.32362
# epoch: 8 	 train_loss: 2.33409 	 test_loss: 1.32644
# epoch: 9 	 train_loss: 2.33124 	 test_loss: 1.32589
# epoch: 10 	 train_loss: 2.32885 	 test_loss: 1.32695
# epoch: 11 	 train_loss: 2.32631 	 test_loss: 1.32520
# epoch: 12 	 train_loss: 2.32411 	 test_loss: 1.32525
# epoch: 13 	 train_loss: 2.32152 	 test_loss: 1.32570
# epoch: 14 	 train_loss: 2.31848 	 test_loss: 1.32645
# epoch: 15 	 train_loss: 2.31778 	 test_loss: 1.32907
# epoch: 16 	 train_loss: 2.31636 	 test_loss: 1.33042
# epoch: 17 	 train_loss: 2.31187 	 test_loss: 1.33435
# epoch: 18 	 train_loss: 2.31154 	 test_loss: 1.33365
# epoch: 19 	 train_loss: 2.30941 	 test_loss: 1.33537
# epoch: 20 	 train_loss: 2.30763 	 test_loss: 1.33745
# epoch: 21 	 train_loss: 2.30592 	 test_loss: 1.33879
# epoch: 22 	 train_loss: 2.30450 	 test_loss: 1.33997
# epoch: 23 	 train_loss: 2.30318 	 test_loss: 1.34106
# epoch: 24 	 train_loss: 2.30220 	 test_loss: 1.34231
# epoch: 25 	 train_loss: 2.30071 	 test_loss: 1.34324
# epoch: 26 	 train_loss: 2.29966 	 test_loss: 1.34416
# epoch: 27 	 train_loss: 2.29838 	 test_loss: 1.34463
# epoch: 28 	 train_loss: 2.29803 	 test_loss: 1.34610
# epoch: 29 	 train_loss: 2.29713 	 test_loss: 1.34807
# epoch: 30 	 train_loss: 2.29644 	 test_loss: 1.34986
# epoch: 31 	 train_loss: 2.29571 	 test_loss: 1.35082
# epoch: 32 	 train_loss: 2.29561 	 test_loss: 1.35188
# epoch: 33 	 train_loss: 2.29509 	 test_loss: 1.35293
# epoch: 34 	 train_loss: 2.29434 	 test_loss: 1.35326
# epoch: 35 	 train_loss: 2.29099 	 test_loss: 1.35586
# epoch: 36 	 train_loss: 2.28909 	 test_loss: 1.35685
# epoch: 37 	 train_loss: 2.28307 	 test_loss: 1.36003
# epoch: 38 	 train_loss: 2.29049 	 test_loss: 1.36099
# epoch: 39 	 train_loss: 2.28521 	 test_loss: 1.36211
# epoch: 40 	 train_loss: 2.27779 	 test_loss: 1.36245
# epoch: 41 	 train_loss: 2.28489 	 test_loss: 1.36234
# epoch: 42 	 train_loss: 2.28105 	 test_loss: 1.36414
# epoch: 43 	 train_loss: 2.28307 	 test_loss: 1.36358
# epoch: 44 	 train_loss: 2.27553 	 test_loss: 1.36511
# epoch: 45 	 train_loss: 2.28027 	 test_loss: 1.36514
# epoch: 46 	 train_loss: 2.27492 	 test_loss: 1.36392
# epoch: 47 	 train_loss: 2.26566 	 test_loss: 1.36760
# epoch: 48 	 train_loss: 2.27955 	 test_loss: 1.36888
# epoch: 49 	 train_loss: 2.28157 	 test_loss: 1.36423
# epoch: 50 	 train_loss: 2.26771 	 test_loss: 1.36569
# epoch: 51 	 train_loss: 2.25922 	 test_loss: 1.37029
# epoch: 52 	 train_loss: 2.27548 	 test_loss: 1.37187
# epoch: 53 	 train_loss: 2.28248 	 test_loss: 1.35434
# epoch: 54 	 train_loss: 2.26296 	 test_loss: 1.35924
# epoch: 55 	 train_loss: 2.24686 	 test_loss: 1.36594
# epoch: 56 	 train_loss: 2.25539 	 test_loss: 1.36662
# epoch: 57 	 train_loss: 2.24437 	 test_loss: 1.37023
# epoch: 58 	 train_loss: 2.24592 	 test_loss: 1.37048
# epoch: 59 	 train_loss: 2.24261 	 test_loss: 1.36848
# epoch: 60 	 train_loss: 2.23882 	 test_loss: 1.37119
# epoch: 61 	 train_loss: 2.23653 	 test_loss: 1.36882
# epoch: 62 	 train_loss: 2.23116 	 test_loss: 1.36875
# epoch: 63 	 train_loss: 2.22565 	 test_loss: 1.37269
# epoch: 64 	 train_loss: 2.22442 	 test_loss: 1.36898
# epoch: 65 	 train_loss: 2.21736 	 test_loss: 1.37213
# epoch: 66 	 train_loss: 2.21459 	 test_loss: 1.37444
# epoch: 67 	 train_loss: 2.21840 	 test_loss: 1.35860
# epoch: 68 	 train_loss: 2.20396 	 test_loss: 1.36640
# epoch: 69 	 train_loss: 2.20864 	 test_loss: 1.36631
# epoch: 70 	 train_loss: 2.20218 	 test_loss: 1.36195
# epoch: 71 	 train_loss: 2.20112 	 test_loss: 1.35571
# epoch: 72 	 train_loss: 2.18417 	 test_loss: 1.36363
# epoch: 73 	 train_loss: 2.19081 	 test_loss: 1.35706
# epoch: 74 	 train_loss: 2.18930 	 test_loss: 1.35485
# epoch: 75 	 train_loss: 2.17685 	 test_loss: 1.35581
# epoch: 76 	 train_loss: 2.17214 	 test_loss: 1.35821
# epoch: 77 	 train_loss: 2.16994 	 test_loss: 1.36045
# epoch: 78 	 train_loss: 2.16969 	 test_loss: 1.35607
# epoch: 79 	 train_loss: 2.15078 	 test_loss: 1.35672
# epoch: 80 	 train_loss: 2.14917 	 test_loss: 1.36051
# epoch: 81 	 train_loss: 2.15608 	 test_loss: 1.35264
# epoch: 82 	 train_loss: 2.14278 	 test_loss: 1.36218
# epoch: 83 	 train_loss: 2.13321 	 test_loss: 1.35960
# epoch: 84 	 train_loss: 2.12242 	 test_loss: 1.36068
# epoch: 85 	 train_loss: 2.11540 	 test_loss: 1.35304
# epoch: 86 	 train_loss: 2.11737 	 test_loss: 1.35154
# epoch: 87 	 train_loss: 2.11343 	 test_loss: 1.34582
# epoch: 88 	 train_loss: 2.09869 	 test_loss: 1.34772
# epoch: 89 	 train_loss: 2.09949 	 test_loss: 1.34507
# epoch: 90 	 train_loss: 2.09120 	 test_loss: 1.35182
# epoch: 91 	 train_loss: 2.36117 	 test_loss: 1.44094
# epoch: 92 	 train_loss: 2.31007 	 test_loss: 1.28857
# epoch: 93 	 train_loss: 2.22033 	 test_loss: 1.32478
# epoch: 94 	 train_loss: 2.19168 	 test_loss: 1.34487
# epoch: 95 	 train_loss: 2.33872 	 test_loss: 1.50276
# epoch: 96 	 train_loss: 2.24755 	 test_loss: 1.35763
# epoch: 97 	 train_loss: 2.20123 	 test_loss: 1.34804
# epoch: 98 	 train_loss: 2.23789 	 test_loss: 1.45370
# epoch: 99 	 train_loss: 2.21174 	 test_loss: 1.28437
# epoch: 100 	 train_loss: 2.22450 	 test_loss: 1.42335
# epoch: 101 	 train_loss: 2.21696 	 test_loss: 1.45612
# epoch: 102 	 train_loss: 2.12417 	 test_loss: 1.36384
# epoch: 103 	 train_loss: 2.14180 	 test_loss: 1.43947
# epoch: 104 	 train_loss: 2.08314 	 test_loss: 1.40358
# epoch: 105 	 train_loss: 2.17680 	 test_loss: 1.35565
# epoch: 106 	 train_loss: 2.11409 	 test_loss: 1.33664
# epoch: 107 	 train_loss: 2.06275 	 test_loss: 1.37723
# epoch: 108 	 train_loss: 2.19382 	 test_loss: 1.39332
# epoch: 109 	 train_loss: 2.14937 	 test_loss: 1.36161
# epoch: 110 	 train_loss: 2.09115 	 test_loss: 1.33947
# epoch: 111 	 train_loss: 2.06597 	 test_loss: 1.34533
# epoch: 112 	 train_loss: 2.04717 	 test_loss: 1.34489
# epoch: 113 	 train_loss: 2.03031 	 test_loss: 1.35020
# epoch: 114 	 train_loss: 2.02413 	 test_loss: 1.34817
# epoch: 115 	 train_loss: 2.02291 	 test_loss: 1.37725
# epoch: 116 	 train_loss: 2.01140 	 test_loss: 1.35805
# epoch: 117 	 train_loss: 2.00102 	 test_loss: 1.37440
# epoch: 118 	 train_loss: 1.99065 	 test_loss: 1.35815
# epoch: 119 	 train_loss: 1.97934 	 test_loss: 1.36148
# epoch: 120 	 train_loss: 1.96966 	 test_loss: 1.34556
# epoch: 121 	 train_loss: 1.96029 	 test_loss: 1.35235
# epoch: 122 	 train_loss: 1.96914 	 test_loss: 1.31887
# epoch: 123 	 train_loss: 1.95255 	 test_loss: 1.31082
# epoch: 124 	 train_loss: 1.95455 	 test_loss: 1.33068
# epoch: 125 	 train_loss: 1.92239 	 test_loss: 1.34422
# epoch: 126 	 train_loss: 2.00925 	 test_loss: 1.37028
# epoch: 127 	 train_loss: 2.07352 	 test_loss: 1.35069
# epoch: 128 	 train_loss: 2.03684 	 test_loss: 1.30672
# epoch: 129 	 train_loss: 1.95414 	 test_loss: 1.29991
# epoch: 130 	 train_loss: 1.89354 	 test_loss: 1.32984
# epoch: 131 	 train_loss: 1.95367 	 test_loss: 1.31729
# epoch: 132 	 train_loss: 1.91540 	 test_loss: 1.27575
# epoch: 133 	 train_loss: 1.93285 	 test_loss: 1.29263
# epoch: 134 	 train_loss: 1.87467 	 test_loss: 1.30081
# epoch: 135 	 train_loss: 1.99637 	 test_loss: 1.29430
# epoch: 136 	 train_loss: 1.89659 	 test_loss: 1.32564
# epoch: 137 	 train_loss: 2.05337 	 test_loss: 1.63277
# epoch: 138 	 train_loss: 2.43362 	 test_loss: 1.61204
# epoch: 139 	 train_loss: 2.46782 	 test_loss: 1.53538
# epoch: 140 	 train_loss: 2.25571 	 test_loss: 1.47605
# epoch: 141 	 train_loss: 2.16792 	 test_loss: 1.42441
# epoch: 142 	 train_loss: 2.11383 	 test_loss: 1.47940
# epoch: 143 	 train_loss: 2.10256 	 test_loss: 1.45336
# epoch: 144 	 train_loss: 2.07637 	 test_loss: 1.45912
# epoch: 145 	 train_loss: 2.06520 	 test_loss: 1.45259
# epoch: 146 	 train_loss: 2.05469 	 test_loss: 1.46099
# epoch: 147 	 train_loss: 2.09798 	 test_loss: 1.43032
# epoch: 148 	 train_loss: 2.10652 	 test_loss: 1.40132
# epoch: 149 	 train_loss: 2.05878 	 test_loss: 1.39809
# epoch: 150 	 train_loss: 2.04607 	 test_loss: 1.40709
# epoch: 151 	 train_loss: 2.02185 	 test_loss: 1.42646
# epoch: 152 	 train_loss: 2.07546 	 test_loss: 1.47903
# epoch: 153 	 train_loss: 2.11668 	 test_loss: 1.39396
# epoch: 154 	 train_loss: 2.03649 	 test_loss: 1.38454
# epoch: 155 	 train_loss: 2.01307 	 test_loss: 1.39908
# epoch: 156 	 train_loss: 1.99851 	 test_loss: 1.41451
# epoch: 157 	 train_loss: 1.99617 	 test_loss: 1.41904
# epoch: 158 	 train_loss: 1.97146 	 test_loss: 1.40565
# epoch: 159 	 train_loss: 1.98478 	 test_loss: 1.42004
# epoch: 160 	 train_loss: 1.95829 	 test_loss: 1.38835
# epoch: 161 	 train_loss: 1.93960 	 test_loss: 1.37930
# epoch: 162 	 train_loss: 2.00437 	 test_loss: 1.59844
# epoch: 163 	 train_loss: 2.22256 	 test_loss: 1.34249
# epoch: 164 	 train_loss: 2.10711 	 test_loss: 1.39343
# epoch: 165 	 train_loss: 2.08127 	 test_loss: 1.36975
# epoch: 166 	 train_loss: 2.00518 	 test_loss: 1.35656
# epoch: 167 	 train_loss: 1.97773 	 test_loss: 1.37799
# epoch: 168 	 train_loss: 1.96527 	 test_loss: 1.37643
# epoch: 169 	 train_loss: 1.95488 	 test_loss: 1.38932
# epoch: 170 	 train_loss: 1.94158 	 test_loss: 1.36657
# epoch: 171 	 train_loss: 1.99021 	 test_loss: 1.34201
# epoch: 172 	 train_loss: 1.95501 	 test_loss: 1.34490
# epoch: 173 	 train_loss: 1.88412 	 test_loss: 1.35444
# epoch: 174 	 train_loss: 1.86776 	 test_loss: 1.37287
# epoch: 175 	 train_loss: 1.89867 	 test_loss: 1.36366
# epoch: 176 	 train_loss: 1.89748 	 test_loss: 1.40300
# epoch: 177 	 train_loss: 1.86043 	 test_loss: 1.38658
# epoch: 178 	 train_loss: 1.86699 	 test_loss: 1.39061
# epoch: 179 	 train_loss: 1.87512 	 test_loss: 1.43927
# epoch: 180 	 train_loss: 1.88517 	 test_loss: 1.38885
# epoch: 181 	 train_loss: 1.90265 	 test_loss: 1.47348
# epoch: 182 	 train_loss: 2.33318 	 test_loss: 1.49661
# epoch: 183 	 train_loss: 2.37345 	 test_loss: 1.52691
# epoch: 184 	 train_loss: 2.21643 	 test_loss: 1.45868
# epoch: 185 	 train_loss: 2.19381 	 test_loss: 1.38772
# epoch: 186 	 train_loss: 2.17148 	 test_loss: 1.44681
# epoch: 187 	 train_loss: 2.23196 	 test_loss: 1.46763
# epoch: 188 	 train_loss: 2.13477 	 test_loss: 1.45394
# epoch: 189 	 train_loss: 2.17817 	 test_loss: 1.49780
# epoch: 190 	 train_loss: 2.29768 	 test_loss: 1.45000
# epoch: 191 	 train_loss: 2.11087 	 test_loss: 1.41302
# epoch: 192 	 train_loss: 2.08461 	 test_loss: 1.39198
# epoch: 193 	 train_loss: 1.95151 	 test_loss: 1.36381
# epoch: 194 	 train_loss: 1.98445 	 test_loss: 1.33061
# epoch: 195 	 train_loss: 1.89572 	 test_loss: 1.35506
# epoch: 196 	 train_loss: 1.88062 	 test_loss: 1.37641
# epoch: 197 	 train_loss: 2.02587 	 test_loss: 1.38579
# epoch: 198 	 train_loss: 1.94081 	 test_loss: 1.34996
# epoch: 199 	 train_loss: 1.86113 	 test_loss: 1.36639
# epoch: 200 	 train_loss: 1.86975 	 test_loss: 1.43760

# %%
model, train_losses, val_losses = train_model(X=X2, y=y2, X_test=X1, y_test=y1, extracted_features=12, n_hiddens=0, layer_size=8, n_ites=100)
plot_loss(train_losses, val_losses, train_set_name='X2', test_set_name='X1')
# Out:
# epoch: 0 	 train_loss: 1.24733 	 test_loss: 2.60933
# epoch: 1 	 train_loss: 1.22263 	 test_loss: 2.58204
# epoch: 2 	 train_loss: 1.21710 	 test_loss: 2.56267
# epoch: 3 	 train_loss: 1.22027 	 test_loss: 2.55668
# epoch: 4 	 train_loss: 1.20661 	 test_loss: 2.55596
# epoch: 5 	 train_loss: 1.19978 	 test_loss: 2.57490
# epoch: 6 	 train_loss: 1.18318 	 test_loss: 2.61268
# epoch: 7 	 train_loss: 1.18354 	 test_loss: 2.58688
# epoch: 8 	 train_loss: 1.17410 	 test_loss: 2.59040
# epoch: 9 	 train_loss: 1.17002 	 test_loss: 2.57443
# epoch: 10 	 train_loss: 1.14761 	 test_loss: 2.65384
# epoch: 11 	 train_loss: 1.17495 	 test_loss: 2.58798
# epoch: 12 	 train_loss: 1.16467 	 test_loss: 2.57983
# epoch: 13 	 train_loss: 1.14783 	 test_loss: 2.63699
# epoch: 14 	 train_loss: 1.13556 	 test_loss: 2.59046
# epoch: 15 	 train_loss: 1.17345 	 test_loss: 2.54187
# epoch: 16 	 train_loss: 1.14219 	 test_loss: 2.62150
# epoch: 17 	 train_loss: 1.15361 	 test_loss: 2.59204
# epoch: 18 	 train_loss: 1.15496 	 test_loss: 2.55324
# epoch: 19 	 train_loss: 1.14503 	 test_loss: 2.58377
# epoch: 20 	 train_loss: 1.15321 	 test_loss: 2.57262
# epoch: 21 	 train_loss: 1.13366 	 test_loss: 2.67682
# epoch: 22 	 train_loss: 1.14243 	 test_loss: 2.57911
# epoch: 23 	 train_loss: 1.13972 	 test_loss: 2.57158
# epoch: 24 	 train_loss: 1.12097 	 test_loss: 2.56265
# epoch: 25 	 train_loss: 1.12397 	 test_loss: 2.58706
# epoch: 26 	 train_loss: 1.12530 	 test_loss: 2.64156
# epoch: 27 	 train_loss: 1.13493 	 test_loss: 2.60997
# epoch: 28 	 train_loss: 1.12423 	 test_loss: 2.61553
# epoch: 29 	 train_loss: 1.15776 	 test_loss: 2.55999
# epoch: 30 	 train_loss: 1.13925 	 test_loss: 2.57162
# epoch: 31 	 train_loss: 1.15036 	 test_loss: 2.61123
# epoch: 32 	 train_loss: 1.17560 	 test_loss: 2.55604
# epoch: 33 	 train_loss: 1.13847 	 test_loss: 2.60591
# epoch: 34 	 train_loss: 1.11433 	 test_loss: 2.57109
# epoch: 35 	 train_loss: 1.12174 	 test_loss: 2.54570
# epoch: 36 	 train_loss: 1.09407 	 test_loss: 2.66448
# epoch: 37 	 train_loss: 1.12564 	 test_loss: 2.52523
# epoch: 38 	 train_loss: 1.09848 	 test_loss: 2.60517
# epoch: 39 	 train_loss: 1.11416 	 test_loss: 2.58936
# epoch: 40 	 train_loss: 1.11355 	 test_loss: 2.57042
# epoch: 41 	 train_loss: 1.10967 	 test_loss: 2.58373
# epoch: 42 	 train_loss: 1.14153 	 test_loss: 2.54217
# epoch: 43 	 train_loss: 1.11034 	 test_loss: 2.59099
# epoch: 44 	 train_loss: 1.09573 	 test_loss: 2.59096
# epoch: 45 	 train_loss: 1.09100 	 test_loss: 2.59675
# epoch: 46 	 train_loss: 1.12125 	 test_loss: 2.52278
# epoch: 47 	 train_loss: 1.09071 	 test_loss: 2.57261
# epoch: 48 	 train_loss: 1.09448 	 test_loss: 2.62431
# epoch: 49 	 train_loss: 1.08644 	 test_loss: 2.57801
# epoch: 50 	 train_loss: 1.08052 	 test_loss: 2.59097
# epoch: 51 	 train_loss: 1.10129 	 test_loss: 2.58039
# epoch: 52 	 train_loss: 1.08612 	 test_loss: 2.58312
# epoch: 53 	 train_loss: 1.08493 	 test_loss: 2.58453
# epoch: 54 	 train_loss: 1.16187 	 test_loss: 2.51551
# epoch: 55 	 train_loss: 1.14898 	 test_loss: 2.56859
# epoch: 56 	 train_loss: 1.12741 	 test_loss: 2.53704
# epoch: 57 	 train_loss: 1.10011 	 test_loss: 2.55718
# epoch: 58 	 train_loss: 1.10307 	 test_loss: 2.56025
# epoch: 59 	 train_loss: 1.10205 	 test_loss: 2.54900
# epoch: 60 	 train_loss: 1.07462 	 test_loss: 2.63733
# epoch: 61 	 train_loss: 1.10421 	 test_loss: 2.55546
# epoch: 62 	 train_loss: 1.09442 	 test_loss: 2.54523
# epoch: 63 	 train_loss: 1.08737 	 test_loss: 2.59536
# epoch: 64 	 train_loss: 1.13920 	 test_loss: 2.64040
# epoch: 65 	 train_loss: 1.13648 	 test_loss: 2.49554
# epoch: 66 	 train_loss: 1.11586 	 test_loss: 2.62538
# epoch: 67 	 train_loss: 1.12122 	 test_loss: 2.63320
# epoch: 68 	 train_loss: 1.09265 	 test_loss: 2.58654
# epoch: 69 	 train_loss: 1.11346 	 test_loss: 2.61610
# epoch: 70 	 train_loss: 1.09945 	 test_loss: 2.60659
# epoch: 71 	 train_loss: 1.10463 	 test_loss: 2.63761
# epoch: 72 	 train_loss: 1.09860 	 test_loss: 2.62521
# epoch: 73 	 train_loss: 1.07074 	 test_loss: 2.54518
# epoch: 74 	 train_loss: 1.06549 	 test_loss: 2.54503
# epoch: 75 	 train_loss: 1.06187 	 test_loss: 2.56011
# epoch: 76 	 train_loss: 1.04512 	 test_loss: 2.54744
# epoch: 77 	 train_loss: 1.04049 	 test_loss: 2.53231
# epoch: 78 	 train_loss: 1.19303 	 test_loss: 2.71475
# epoch: 79 	 train_loss: 1.15658 	 test_loss: 2.68468
# epoch: 80 	 train_loss: 1.14431 	 test_loss: 2.69996
# epoch: 81 	 train_loss: 1.13378 	 test_loss: 2.69659
# epoch: 82 	 train_loss: 1.13677 	 test_loss: 2.58565
# epoch: 83 	 train_loss: 1.12334 	 test_loss: 2.57464
# epoch: 84 	 train_loss: 1.10881 	 test_loss: 2.54954
# epoch: 85 	 train_loss: 1.09169 	 test_loss: 2.54580
# epoch: 86 	 train_loss: 1.07778 	 test_loss: 2.55673
# epoch: 87 	 train_loss: 1.05489 	 test_loss: 2.53913
# epoch: 88 	 train_loss: 1.05882 	 test_loss: 2.55567
# epoch: 89 	 train_loss: 1.06600 	 test_loss: 2.52325
# epoch: 90 	 train_loss: 1.05661 	 test_loss: 2.48716
# epoch: 91 	 train_loss: 1.07549 	 test_loss: 2.47224
# epoch: 92 	 train_loss: 1.04814 	 test_loss: 2.58681
# epoch: 93 	 train_loss: 1.07761 	 test_loss: 2.54247
# epoch: 94 	 train_loss: 1.06349 	 test_loss: 2.45572
# epoch: 95 	 train_loss: 1.05576 	 test_loss: 2.46576
# epoch: 96 	 train_loss: 1.05445 	 test_loss: 2.46646
# epoch: 97 	 train_loss: 1.04896 	 test_loss: 2.42492
# epoch: 98 	 train_loss: 1.04095 	 test_loss: 2.58153
# epoch: 99 	 train_loss: 1.04844 	 test_loss: 2.55877
# epoch: 100 	 train_loss: 1.04898 	 test_loss: 2.45251
